# %% [markdown]
# # Question 1: MongoDB - Northwind Database
#
# This notebook implements MongoDB with the Northwind database.
#
# ## Database Design Explanation
#
# ### Embedding vs Referencing Strategy:
#
# 1. **Categories in Products (Embedded)**: Category information is embedded directly into product documents:
#    - Categories are static and small (only 8 categories)
#    - Products usually need category information for display
#    - One product belongs to exactly one category
#
# 2. **Suppliers in Products (Referenced with ObjectId)**: Supplier information is referenced using ObjectId:
#    - Supplier data is more extensive and changes over time (contact info, address)
#    - Multiple products share the same supplier—embedding would duplicate data
#    - Supplier updates don't require modifying all related products
#
# 3. **Order Details in Orders (Embedded)**: Order details (product items) are embedded within order documents:
#    - Order details have a strong "contains" relationship with orders
#    - Order details are always accessed together with orders
#    - Order details don't exist independently of their parent order
#    - This follows MongoDB's common "order pattern"

# %%
# Install required packages
# !pip install "pymongo[srv]" pandas
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: pymongo[srv] in /opt/anaconda3/lib/python3.12/site-packages (4.15.5)
# WARNING: pymongo 4.15.5 does not provide the extra 'srv'
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /opt/anaconda3/lib/python3.12/site-packages (from pymongo[srv]) (2.8.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Import libraries
from pymongo import MongoClient
from bson.objectid import ObjectId
import pandas as pd
import os
from datetime import datetime

# Connect to MongoDB Atlas
# Connection string: mongodb+srv://<username>:<password>@<cluster-url>
MONGO_URI = "mongodb+srv://Simon:ZjkLSE66666666!@cluster0.lr8y4n4.mongodb.net/?appName=Cluster0"

client = MongoClient(MONGO_URI)

# Test connection
try:
    client.admin.command('ping')
    print("Successfully connected to MongoDB Atlas!")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Successfully connected to MongoDB Atlas!

# %% [markdown]
# ## 1A) Create Database and Load CSV Files
#
# Create a new database called `Northwind` and load each CSV file into a new collection.

# %%
# Create/Access the Northwind database
db = client["Northwind"]

# Drop existing collections (for re-running)
for collection_name in db.list_collection_names():
    db.drop_collection(collection_name)
    print(f"Dropped collection: {collection_name}")

print("\nDatabase 'Northwind' is ready.")
# Out:
# Dropped collection: employees
# Dropped collection: orders
# Dropped collection: products
# Dropped collection: customers
# Dropped collection: customer_sales_summary
# Dropped collection: categories
# Dropped collection: suppliers
#
# Database 'Northwind' is ready.

# %%
# Load CSV files
data_path = "./data/"

# Load all CSV files into DataFrames
categories_df = pd.read_csv(os.path.join(data_path, "categories.csv"))
customers_df = pd.read_csv(os.path.join(data_path, "customers.csv"))
employees_df = pd.read_csv(os.path.join(data_path, "employees.csv"))
orders_df = pd.read_csv(os.path.join(data_path, "orders.csv"))
products_df = pd.read_csv(os.path.join(data_path, "products.csv"))
suppliers_df = pd.read_csv(os.path.join(data_path, "suppliers.csv"))

print("CSV files loaded successfully!")
print(f"\nCategories: {len(categories_df)} records")
print(f"Customers: {len(customers_df)} records")
print(f"Employees: {len(employees_df)} records")
print(f"Orders (with details): {len(orders_df)} records")
print(f"Products: {len(products_df)} records")
print(f"Suppliers: {len(suppliers_df)} records")
# Out:
# CSV files loaded successfully!
#
# Categories: 8 records
# Customers: 91 records
# Employees: 9 records
# Orders (with details): 2155 records
# Products: 77 records
# Suppliers: 29 records

# %%
# Load Categories collection (for embedding in products)
categories_dict = {}  # Mapping for embedding

categories_docs = []
for _, row in categories_df.iterrows():
    doc = {
        "_id": ObjectId(),
        "categoryId": int(row["CategoryID"]),
        "categoryName": row["CategoryName"],
        "description": row["Description"]
    }
    categories_dict[int(row["CategoryID"])] = {
        "_id": doc["_id"],
        "categoryId": doc["categoryId"],
        "categoryName": doc["categoryName"],
        "description": doc["description"]
    }
    categories_docs.append(doc)

db["categories"].insert_many(categories_docs)
print(f"Inserted {len(categories_docs)} categories")
# Out:
# Inserted 8 categories

# %%
# Load Suppliers collection (referenced by ObjectId in products)
suppliers_dict = {}  # Mapping: SupplierID -> ObjectId

suppliers_docs = []
for _, row in suppliers_df.iterrows():
    doc = {
        "_id": ObjectId(),
        "supplierId": int(row["SupplierID"]),
        "companyName": row["CompanyName"],
        "contactName": row["ContactName"] if pd.notna(row["ContactName"]) else None,
        "contactTitle": row["ContactTitle"] if pd.notna(row["ContactTitle"]) else None,
        "address": row["Address"] if pd.notna(row["Address"]) else None,
        "city": row["City"] if pd.notna(row["City"]) else None,
        "region": row["Region"] if pd.notna(row["Region"]) else None,
        "postalCode": row["PostalCode"] if pd.notna(row["PostalCode"]) else None,
        "country": row["Country"] if pd.notna(row["Country"]) else None,
        "phone": row["Phone"] if pd.notna(row["Phone"]) else None,
        "fax": row["Fax"] if pd.notna(row["Fax"]) else None,
        "homePage": row["HomePage"] if pd.notna(row["HomePage"]) else None
    }
    suppliers_dict[int(row["SupplierID"])] = doc["_id"]
    suppliers_docs.append(doc)

db["suppliers"].insert_many(suppliers_docs)
print(f"Inserted {len(suppliers_docs)} suppliers")
# Out:
# Inserted 29 suppliers

# %%
# Load Products collection
# Products have: embedded category, referenced supplier (ObjectId)
products_dict = {}  # Mapping: ProductID -> document info

products_docs = []
for _, row in products_df.iterrows():
    supplier_id = int(row["SupplierID"]) if pd.notna(row["SupplierID"]) else None
    category_id = int(row["CategoryID"]) if pd.notna(row["CategoryID"]) else None
    
    doc = {
        "_id": ObjectId(),
        "productId": int(row["ProductID"]),
        "productName": row["ProductName"],
        "quantityPerUnit": row["QuantityPerUnit"] if pd.notna(row["QuantityPerUnit"]) else None,
        "unitPrice": float(row["UnitPrice"]) if pd.notna(row["UnitPrice"]) else 0,
        "unitsInStock": int(row["UnitsInStock"]) if pd.notna(row["UnitsInStock"]) else 0,
        "unitsOnOrder": int(row["UnitsOnOrder"]) if pd.notna(row["UnitsOnOrder"]) else 0,
        "reorderLevel": int(row["ReorderLevel"]) if pd.notna(row["ReorderLevel"]) else 0,
        "discontinued": bool(int(row["Discontinued"])) if pd.notna(row["Discontinued"]) else False,
        # Supplier reference (ObjectId)
        "supplier_id": suppliers_dict.get(supplier_id) if supplier_id else None,
        # Embedded category
        "category": categories_dict.get(category_id) if category_id else None
    }
    
    products_dict[int(row["ProductID"])] = {
        "_id": doc["_id"],
        "productId": doc["productId"],
        "productName": doc["productName"],
        "unitPrice": doc["unitPrice"],
        "category": doc["category"]
    }
    products_docs.append(doc)

db["products"].insert_many(products_docs)
print(f"Inserted {len(products_docs)} products")
# Out:
# Inserted 77 products

# %%
# Load Customers collection
customers_dict = {}  # Mapping: CustomerID -> document

customers_docs = []
for _, row in customers_df.iterrows():
    doc = {
        "_id": ObjectId(),
        "customerId": row["CustomerID"],
        "companyName": row["CompanyName"],
        "contactName": row["ContactName"] if pd.notna(row["ContactName"]) else None,
        "contactTitle": row["ContactTitle"] if pd.notna(row["ContactTitle"]) else None,
        "address": row["Address"] if pd.notna(row["Address"]) else None,
        "city": row["City"] if pd.notna(row["City"]) else None,
        "region": row["Region"] if pd.notna(row["Region"]) else None,
        "postalCode": str(row["PostalCode"]) if pd.notna(row["PostalCode"]) else None,
        "country": row["Country"] if pd.notna(row["Country"]) else None,
        "phone": row["Phone"] if pd.notna(row["Phone"]) else None,
        "fax": row["Fax"] if pd.notna(row["Fax"]) else None
    }
    customers_dict[row["CustomerID"]] = doc
    customers_docs.append(doc)

db["customers"].insert_many(customers_docs)
print(f"Inserted {len(customers_docs)} customers")
# Out:
# Inserted 91 customers

# %%
# Load Employees collection
employees_dict = {}  # Mapping: EmployeeID -> ObjectId

employees_docs = []
for _, row in employees_df.iterrows():
    doc = {
        "_id": ObjectId(),
        "employeeId": int(row["EmployeeID"]),
        "lastName": row["LastName"],
        "firstName": row["FirstName"],
        "title": row["Title"] if pd.notna(row["Title"]) else None,
        "titleOfCourtesy": row["TitleOfCourtesy"] if pd.notna(row["TitleOfCourtesy"]) else None,
        "birthDate": row["BirthDate"] if pd.notna(row["BirthDate"]) else None,
        "hireDate": row["HireDate"] if pd.notna(row["HireDate"]) else None,
        "address": row["Address"] if pd.notna(row["Address"]) else None,
        "city": row["City"] if pd.notna(row["City"]) else None,
        "region": row["Region"] if pd.notna(row["Region"]) else None,
        "postalCode": row["PostalCode"] if pd.notna(row["PostalCode"]) else None,
        "country": row["Country"] if pd.notna(row["Country"]) else None,
        "homePhone": row["HomePhone"] if pd.notna(row["HomePhone"]) else None,
        "extension": row["Extension"] if pd.notna(row["Extension"]) else None,
        "notes": row["Notes"] if pd.notna(row["Notes"]) else None,
        "reportsTo": int(row["ReportsTo"]) if pd.notna(row["ReportsTo"]) else None
    }
    employees_dict[int(row["EmployeeID"])] = doc["_id"]
    employees_docs.append(doc)

db["employees"].insert_many(employees_docs)
print(f"Inserted {len(employees_docs)} employees")
# Out:
# Inserted 9 employees

# %%
# Load Orders collection
# Orders and Order_Details are merged in CSV
# Embed order details (products) within each order document

# Group orders by OrderID and aggregate order details
orders_grouped = {}

for _, row in orders_df.iterrows():
    order_id = int(row["OrderID"])
    
    if order_id not in orders_grouped:
        customer_id = row["CustomerID"]
        employee_id = int(row["EmployeeID"]) if pd.notna(row["EmployeeID"]) else None
        
        orders_grouped[order_id] = {
            "_id": ObjectId(),
            "orderId": order_id,
            # Reference to customer using ObjectId
            "customer_id": customers_dict.get(customer_id, {}).get("_id") if customer_id else None,
            "customerId": customer_id,  # Keep original ID for convenience
            # Reference to employee using ObjectId
            "employee_id": employees_dict.get(employee_id) if employee_id else None,
            "employeeId": employee_id,
            "orderDate": row["OrderDate"] if pd.notna(row["OrderDate"]) else None,
            "requiredDate": row["RequiredDate"] if pd.notna(row["RequiredDate"]) else None,
            "shippedDate": row["ShippedDate"] if pd.notna(row["ShippedDate"]) else None,
            "shipVia": int(row["ShipVia"]) if pd.notna(row["ShipVia"]) else None,
            "freight": float(row["Freight"]) if pd.notna(row["Freight"]) else 0,
            "shipName": row["ShipName"] if pd.notna(row["ShipName"]) else None,
            "shipAddress": row["ShipAddress"] if pd.notna(row["ShipAddress"]) else None,
            "shipCity": row["ShipCity"] if pd.notna(row["ShipCity"]) else None,
            "shipRegion": row["ShipRegion"] if pd.notna(row["ShipRegion"]) else None,
            "shipPostalCode": str(row["ShipPostalCode"]) if pd.notna(row["ShipPostalCode"]) else None,
            "shipCountry": row["ShipCountry"] if pd.notna(row["ShipCountry"]) else None,
            # Embedded order details
            "orderDetails": []
        }
    
    # Add order detail (embedded)
    product_id = int(row["ProductID"]) if pd.notna(row["ProductID"]) else None
    product_info = products_dict.get(product_id, {})
    
    order_detail = {
        "product_id": product_info.get("_id"),
        "productId": product_id,
        "productName": product_info.get("productName"),
        "unitPrice": float(row["UnitPrice"]) if pd.notna(row["UnitPrice"]) else 0,
        "quantity": int(row["Quantity"]) if pd.notna(row["Quantity"]) else 0,
        "discount": float(row["Discount"]) if pd.notna(row["Discount"]) else 0,
        "category": product_info.get("category")
    }
    orders_grouped[order_id]["orderDetails"].append(order_detail)

# Insert all orders
orders_docs = list(orders_grouped.values())
db["orders"].insert_many(orders_docs)
print(f"Inserted {len(orders_docs)} orders")
# Out:
# Inserted 830 orders

# %%
# Verify data loaded correctly
print("=== Collection Statistics ===")
for collection_name in db.list_collection_names():
    count = db[collection_name].count_documents({})
    print(f"{collection_name}: {count} documents")
# Out:
# === Collection Statistics ===
# orders: 830 documents
# suppliers: 29 documents
# products: 77 documents
# customers: 91 documents
# categories: 8 documents
# employees: 9 documents

# %%
# Show sample documents
print("=== Sample Product Document (showing embedded category and referenced supplier) ===")
sample_product = db["products"].find_one()
for key, value in sample_product.items():
    print(f"{key}: {value}")
# Out:
# === Sample Product Document (showing embedded category and referenced supplier) ===
# _id: 69334ffcee08578b3fda2a71
# productId: 1
# productName: Chai
# quantityPerUnit: 10 boxes x 30 bags
# unitPrice: 18.0
# unitsInStock: 39
# unitsOnOrder: 0
# reorderLevel: 10
# discontinued: True
# supplier_id: 69334ffcee08578b3fda2a5b
# category: {'_id': ObjectId('69334ffcee08578b3fda2a4c'), 'categoryId': 1, 'categoryName': 'Beverages', 'description': 'Soft drinks, coffees, teas, beers, and ales'}

# %%
print("=== Sample Order Document (showing embedded order details) ===")
sample_order = db["orders"].find_one()
for key, value in sample_order.items():
    if key == "orderDetails":
        print(f"{key}: [{len(value)} items]")
        for detail in value[:2]:  # Show first 2
            print(f"  - {detail}")
    else:
        print(f"{key}: {value}")
# Out:
# === Sample Order Document (showing embedded order details) ===
# _id: 69334ffeee08578b3fda2b22
# orderId: 10248
# customer_id: 69334ffdee08578b3fda2b12
# customerId: VINET
# employee_id: 69334ffeee08578b3fda2b1d
# employeeId: 5
# orderDate: 1996-07-04
# requiredDate: 1996-08-01
# shippedDate: 1996-07-16
# shipVia: 3
# freight: 32.38
# shipName: Vins et alcools Chevalier
# shipAddress: 59 rue de l'Abbaye
# shipCity: Reims
# shipRegion: None
# shipPostalCode: 51100
# shipCountry: France
# orderDetails: [3 items]
#   - {'product_id': ObjectId('69334ffcee08578b3fda2a7b'), 'productId': 11, 'productName': 'Queso Cabrales', 'unitPrice': 14.0, 'quantity': 12, 'discount': 0.0, 'category': {'_id': ObjectId('69334ffcee08578b3fda2a4f'), 'categoryId': 4, 'categoryName': 'Dairy Products', 'description': 'Cheeses'}}
#   - {'product_id': ObjectId('69334ffcee08578b3fda2a9a'), 'productId': 42, 'productName': 'Singaporean Hokkien Fried Mee', 'unitPrice': 9.8, 'quantity': 10, 'discount': 0.0, 'category': {'_id': ObjectId('69334ffcee08578b3fda2a50'), 'categoryId': 5, 'categoryName': 'Grains/Cereals', 'description': 'Breads, crackers, pasta, and cereal'}}

# %% [markdown]
# ## 1B) List Products and Unit Prices by Supplier
#
# List all product names and unit prices supplied by each company (supplier), along with the supplier's name. The output should have one document per supplier.
#
# This query uses an aggregation pipeline that:
# 1. `$lookup` - joins products with suppliers using the supplier_id reference
# 2. `$unwind` - flattens the supplier array from lookup
# 3. `$group` - groups products by supplier, creating one document per supplier
# 4. `$project` - formats the output with supplier info and product list

# %%
# Query 1B: Products by Supplier
# Use $lookup to join products with suppliers, then $group by supplier

pipeline_1b = [
    # Filter products with suppliers
    {
        "$match": {
            "supplier_id": {"$ne": None}
        }
    },
    # Join with suppliers collection
    {
        "$lookup": {
            "from": "suppliers",
            "localField": "supplier_id",
            "foreignField": "_id",
            "as": "supplier"
        }
    },
    # Unwind supplier array ($lookup returns array)
    {
        "$unwind": "$supplier"
    },
    # Group by supplier
    {
        "$group": {
            "_id": "$supplier._id",
            "supplierName": {"$first": "$supplier.companyName"},
            "contactName": {"$first": "$supplier.contactName"},
            "country": {"$first": "$supplier.country"},
            "products": {
                "$push": {
                    "productName": "$productName",
                    "unitPrice": "$unitPrice"
                }
            }
        }
    },
    # Format output
    {
        "$project": {
            "_id": 0,
            "supplierName": 1,
            "contactName": 1,
            "country": 1,
            "products": 1,
            "productCount": {"$size": "$products"}
        }
    },
    # Sort by supplier name
    {
        "$sort": {"supplierName": 1}
    }
]

result_1b = list(db["products"].aggregate(pipeline_1b))

print(f"Total suppliers: {len(result_1b)}")
print("\n=== Products by Supplier ===")
for doc in result_1b:
    print(f"\n--- {doc['supplierName']} ({doc['country']}) ---")
    print(f"Contact: {doc['contactName']}")
    print(f"Number of products: {doc['productCount']}")
    print("Products:")
    for product in doc['products']:
        print(f"  - {product['productName']}: ${product['unitPrice']:.2f}")
# Out:
# Total suppliers: 29
#
# === Products by Supplier ===
#
# --- Aux joyeux ecclésiastiques (France) ---
# Contact: Guylène Nodier
# Number of products: 2
# Products:
#   - Côte de Blaye: $263.50
#   - Chartreuse verte: $18.00
#
# --- Bigfoot Breweries (USA) ---
# Contact: Cheryl Saylor
# Number of products: 3
# Products:
#   - Sasquatch Ale: $14.00
#   - Steeleye Stout: $18.00
#   - Laughing Lumberjack Lager: $14.00
#
# --- Cooperativa de Quesos 'Las Cabras' (Spain) ---
# Contact: Antonio del Valle Saavedra
# Number of products: 2
# Products:
#   - Queso Cabrales: $21.00
#   - Queso Manchego La Pastora: $38.00
#
# --- Escargots Nouveaux (France) ---
# Contact: Marie Delamare
# Number of products: 1
# Products:
#   - Escargots de Bourgogne: $13.25
#
# --- Exotic Liquids (UK) ---
# Contact: Charlotte Cooper
# Number of products: 2
# Products:
#   - Chang: $19.00
#   - Aniseed Syrup: $10.00
#
# --- Formaggi Fortini s.r.l. (Italy) ---
# Contact: Elio Rossi
# Number of products: 3
# Products:
#   - Gorgonzola Telino: $12.50
#   - Mascarpone Fabioli: $32.00
#   - Mozzarella di Giovanni: $34.80
#
# --- Forêts d'érables (Canada) ---
# Contact: Chantal Goulet
# Number of products: 2
# Products:
#   - Sirop d'érable: $28.50
#   - Tarte au sucre: $49.30
#
# --- G'day, Mate (Australia) ---
# Contact: Wendy Mackenzie
# Number of products: 3
# Products:
#   - Manjimup Dried Apples: $53.00
#   - Filo Mix: $7.00
#   - Perth Pasties: $32.80
#
# --- Gai pâturage (France) ---
# Contact: Eliane Noz
# Number of products: 2
# Products:
#   - Raclette Courdavault: $55.00
#   - Camembert Pierrot: $34.00
#
# --- Grandma Kelly's Homestead (USA) ---
# Contact: Regina Murphy
# Number of products: 3
# Products:
#   - Grandma's Boysenberry Spread: $25.00
#   - Uncle Bob's Organic Dried Pears: $30.00
#   - Northwoods Cranberry Sauce: $40.00
#
# --- Heli Süßwaren GmbH & Co. KG (Germany) ---
# Contact: Petra Winkler
# Number of products: 3
# Products:
#   - NuNuCa Nuß-Nougat-Creme: $14.00
#   - Gumbär Gummibärchen: $31.23
#   - Schoggi Schokolade: $43.90
#
# --- Karkki Oy (Finland) ---
# Contact: Anne Heikkonen
# Number of products: 3
# Products:
#   - Maxilaku: $20.00
#   - Valkoinen suklaa: $16.25
#   - Lakkalikööri: $18.00
#
# --- Leka Trading (Singapore) ---
# Contact: Chandra Leka
# Number of products: 3
# Products:
#   - Singaporean Hokkien Fried Mee: $14.00
#   - Ipoh Coffee: $46.00
#   - Gula Malacca: $19.45
#
# --- Lyngbysild (Denmark) ---
# Contact: Niels Petersen
# Number of products: 2
# Products:
#   - Rogede sild: $9.50
#   - Spegesild: $12.00
#
# --- Ma Maison (Canada) ---
# Contact: Jean-Guy Lauzon
# Number of products: 2
# Products:
#   - Tourtière: $7.45
#   - Pâté chinois: $24.00
#
# --- Mayumi's (Japan) ---
# Contact: Mayumi Ohno
# Number of products: 3
# Products:
#   - Konbu: $6.00
#   - Tofu: $23.25
#   - Genen Shouyu: $13.00
#
# --- New England Seafood Cannery (USA) ---
# Contact: Robb Merchant
# Number of products: 2
# Products:
#   - Boston Crab Meat: $18.40
#   - Jack's New England Clam Chowder: $9.65
#
# --- New Orleans Cajun Delights (USA) ---
# Contact: Shelley Burke
# Number of products: 4
# Products:
#   - Chef Anton's Cajun Seasoning: $22.00
#   - Chef Anton's Gumbo Mix: $21.35
#   - Louisiana Fiery Hot Pepper Sauce: $21.05
#   - Louisiana Hot Spiced Okra: $17.00
#
# --- Nord-Ost-Fisch Handelsgesellschaft mbH (Germany) ---
# Contact: Sven Petersen
# Number of products: 1
# Products:
#   - Nord-Ost Matjeshering: $25.89
#
# --- Norske Meierier (Norway) ---
# Contact: Beate Vileid
# Number of products: 3
# Products:
#   - Geitost: $2.50
#   - Gudbrandsdalsost: $36.00
#   - Flotemysost: $21.50
#
# --- PB Knäckebröd AB (Sweden) ---
# Contact: Lars Peterson
# Number of products: 2
# Products:
#   - Gustaf's Knäckebröd: $21.00
#   - Tunnbröd: $9.00
#
# --- Pasta Buttini s.r.l. (Italy) ---
# Contact: Giovanni Giudici
# Number of products: 2
# Products:
#   - Gnocchi di nonna Alice: $38.00
#   - Ravioli Angelo: $19.50
#
# --- Pavlova, Ltd. (Australia) ---
# Contact: Ian Devling
# Number of products: 5
# Products:
#   - Pavlova: $17.45
#   - Alice Mutton: $39.00
#   - Carnarvon Tigers: $62.50
#   - Vegie-spread: $43.90
#   - Outback Lager: $15.00
#
# --- Plutzer Lebensmittelgroßmärkte AG (Germany) ---
# Contact: Martin Bein
# Number of products: 5
# Products:
#   - Rössle Sauerkraut: $45.60
#   - Thüringer Rostbratwurst: $123.79
#   - Wimmers gute Semmelknödel: $33.25
#   - Rhönbräu Klosterbier: $7.75
#   - Original Frankfurter grüne Soße: $13.00
#
# --- Refrescos Americanas LTDA (Brazil) ---
# Contact: Carlos Diaz
# Number of products: 1
# Products:
#   - Guaraná Fantástica: $4.50
#
# --- Specialty Biscuits, Ltd. (UK) ---
# Contact: Peter Wilson
# Number of products: 5
# Products:
#   - Chai: $18.00
#   - Teatime Chocolate Biscuits: $9.20
#   - Sir Rodney's Marmalade: $81.00
#   - Sir Rodney's Scones: $10.00
#   - Scottish Longbreads: $12.50
#
# --- Svensk Sjöföda AB (Sweden) ---
# Contact: Michael Björn
# Number of products: 3
# Products:
#   - Inlagd Sill: $19.00
#   - Gravad lax: $26.00
#   - Röd Kaviar: $15.00
#
# --- Tokyo Traders (Japan) ---
# Contact: Yoshi Nagase
# Number of products: 3
# Products:
#   - Mishi Kobe Niku: $97.00
#   - Ikura: $31.00
#   - Longlife Tofu: $10.00
#
# --- Zaanse Snoepfabriek (Netherlands) ---
# Contact: Dirk Luchte
# Number of products: 2
# Products:
#   - Zaanse koeken: $9.50
#   - Chocolade: $12.75

# %% [markdown]
# ## 1C) List Products Purchased by Each Customer
#
# For each customer, list all the products they have purchased with product name, total quantity purchased, and total spent.
#
# This query uses an aggregation pipeline that:
# 1. `$unwind` - expands embedded order details
# 2. `$lookup` - joins with customer information
# 3. `$group` (first) - groups by customer and product to calculate per-product totals
# 4. `$group` (second) - aggregates all products for each customer
# 5. Calculates total spent as: unitPrice × quantity × (1 - discount)

# %%
# Query 1C: Products purchased by each customer
# Unwind order details, then group by customer and product

pipeline_1c = [
    # Unwind order details for product-level processing
    {
        "$unwind": "$orderDetails"
    },
    # Lookup customer information
    {
        "$lookup": {
            "from": "customers",
            "localField": "customer_id",
            "foreignField": "_id",
            "as": "customer"
        }
    },
    {
        "$unwind": "$customer"
    },
    # Group by customer and product to calculate totals
    {
        "$group": {
            "_id": {
                "customerId": "$customer._id",
                "productId": "$orderDetails.productId"
            },
            "customerInfo": {"$first": "$customer"},
            "productName": {"$first": "$orderDetails.productName"},
            "totalQuantity": {"$sum": "$orderDetails.quantity"},
            "totalSpent": {
                "$sum": {
                    "$multiply": [
                        "$orderDetails.unitPrice",
                        "$orderDetails.quantity",
                        {"$subtract": [1, "$orderDetails.discount"]}
                    ]
                }
            }
        }
    },
    # Group by customer to build product list
    {
        "$group": {
            "_id": "$_id.customerId",
            "customerId": {"$first": "$customerInfo.customerId"},
            "companyName": {"$first": "$customerInfo.companyName"},
            "contactName": {"$first": "$customerInfo.contactName"},
            "city": {"$first": "$customerInfo.city"},
            "country": {"$first": "$customerInfo.country"},
            "products": {
                "$push": {
                    "productName": "$productName",
                    "totalQuantity": "$totalQuantity",
                    "totalSpent": {"$round": ["$totalSpent", 2]}
                }
            },
            "grandTotalSpent": {"$sum": "$totalSpent"}
        }
    },
    # Project final format
    {
        "$project": {
            "_id": 0,
            "customerId": 1,
            "companyName": 1,
            "contactName": 1,
            "city": 1,
            "country": 1,
            "products": 1,
            "totalProducts": {"$size": "$products"},
            "grandTotalSpent": {"$round": ["$grandTotalSpent", 2]}
        }
    },
    # Sort by company name
    {
        "$sort": {"companyName": 1}
    }
]

result_1c = list(db["orders"].aggregate(pipeline_1c))

print(f"Total customers with purchases: {len(result_1c)}")
# Out:
# Total customers with purchases: 89

# %%
# Display results for 1C
print("=== Customer Purchase Summary ===")

# Show first 5 customers as examples
for doc in result_1c[:5]:
    print(f"\n--- {doc['companyName']} ({doc['customerId']}) ---")
    print(f"Contact: {doc['contactName']}")
    print(f"Location: {doc['city']}, {doc['country']}")
    print(f"Total unique products purchased: {doc['totalProducts']}")
    print(f"Grand total spent: ${doc['grandTotalSpent']:.2f}")
    print("Products purchased (top 5 by spending):")
    # Sort products by total spent and show top 5
    sorted_products = sorted(doc['products'], key=lambda x: x['totalSpent'], reverse=True)[:5]
    for product in sorted_products:
        print(f"  - {product['productName']}: Qty {product['totalQuantity']}, ${product['totalSpent']:.2f}")

print("\n... (showing first 5 customers)")
# Out:
# === Customer Purchase Summary ===
#
# --- Alfreds Futterkiste (ALFKI) ---
# Contact: Maria Anders
# Location: Berlin, Germany
# Total unique products purchased: 11
# Grand total spent: $4273.00
# Products purchased (top 5 by spending):
#   - Vegie-spread: Qty 20, $878.00
#   - Raclette Courdavault: Qty 15, $825.00
#   - Rössle Sauerkraut: Qty 17, $604.20
#   - Escargots de Bourgogne: Qty 40, $503.50
#   - Flotemysost: Qty 20, $430.00
#
# --- Ana Trujillo Emparedados y helados (ANATR) ---
# Contact: Ana Trujillo
# Location: México D.F., Mexico
# Total unique products purchased: 10
# Grand total spent: $1402.95
# Products purchased (top 5 by spending):
#   - Mozzarella di Giovanni: Qty 10, $348.00
#   - Camembert Pierrot: Qty 10, $340.00
#   - Mascarpone Fabioli: Qty 10, $320.00
#   - Singaporean Hokkien Fried Mee: Qty 5, $70.00
#   - Tofu: Qty 3, $69.75
#
# --- Antonio Moreno Taquería (ANTON) ---
# Contact: Antonio Moreno
# Location: México D.F., Mexico
# Total unique products purchased: 15
# Grand total spent: $7023.98
# Products purchased (top 5 by spending):
#   - Queso Cabrales: Qty 74, $1348.20
#   - Perth Pasties: Qty 25, $820.00
#   - Gumbär Gummibärchen: Qty 30, $796.37
#   - Raclette Courdavault: Qty 15, $742.50
#   - Alice Mutton: Qty 18, $702.00
#
# --- Around the Horn (AROUT) ---
# Contact: Thomas Hardy
# Location: London, UK
# Total unique products purchased: 24
# Grand total spent: $13390.65
# Products purchased (top 5 by spending):
#   - Sir Rodney's Marmalade: Qty 50, $3847.50
#   - Gorgonzola Telino: Qty 115, $1406.25
#   - Ravioli Angelo: Qty 65, $1170.00
#   - Manjimup Dried Apples: Qty 20, $1060.00
#   - Outback Lager: Qty 53, $627.00
#
# --- B's Beverages (BSBEV) ---
# Contact: Victoria Ashworth
# Location: London, UK
# Total unique products purchased: 19
# Grand total spent: $6089.90
# Products purchased (top 5 by spending):
#   - Ipoh Coffee: Qty 30, $1380.00
#   - Uncle Bob's Organic Dried Pears: Qty 34, $840.00
#   - Gnocchi di nonna Alice: Qty 20, $608.00
#   - Tarte au sucre: Qty 10, $493.00
#   - Gustaf's Knäckebröd: Qty 21, $441.00
#
# ... (showing first 5 customers)

# %%
# Display all customers (complete output for 1C)
print("=== Complete Customer Purchase Data ===")
for doc in result_1c:
    print(f"\n{'='*60}")
    print(f"Customer: {doc['companyName']}")
    print(f"Customer ID: {doc['customerId']}")
    print(f"Contact: {doc['contactName']}")
    print(f"Location: {doc['city']}, {doc['country']}")
    print(f"Total Products Purchased: {doc['totalProducts']}")
    print(f"Grand Total Spent: ${doc['grandTotalSpent']:.2f}")
    print("-" * 40)
    print("Products:")
    for product in sorted(doc['products'], key=lambda x: x['totalSpent'], reverse=True):
        print(f"  • {product['productName']}: Qty {product['totalQuantity']}, Total ${product['totalSpent']:.2f}")
# Out:
# === Complete Customer Purchase Data ===
#
# ============================================================
# Customer: Alfreds Futterkiste
# Customer ID: ALFKI
# Contact: Maria Anders
# Location: Berlin, Germany
# Total Products Purchased: 11
# Grand Total Spent: $4273.00
# ----------------------------------------
# Products:
#   • Vegie-spread: Qty 20, Total $878.00
#   • Raclette Courdavault: Qty 15, Total $825.00
#   • Rössle Sauerkraut: Qty 17, Total $604.20
#   • Escargots de Bourgogne: Qty 40, Total $503.50
#   • Flotemysost: Qty 20, Total $430.00
#   • Grandma's Boysenberry Spread: Qty 16, Total $380.00
#   • Chartreuse verte: Qty 21, Total $283.50
#   • Lakkalikööri: Qty 15, Total $270.00
#   • Aniseed Syrup: Qty 6, Total $60.00
#   • Original Frankfurter grüne Soße: Qty 2, Total $20.80
#   • Spegesild: Qty 2, Total $18.00
#
# ============================================================
# Customer: Ana Trujillo Emparedados y helados
# Customer ID: ANATR
# Contact: Ana Trujillo
# Location: México D.F., Mexico
# Total Products Purchased: 10
# Grand Total Spent: $1402.95
# ----------------------------------------
# Products:
#   • Mozzarella di Giovanni: Qty 10, Total $348.00
#   • Camembert Pierrot: Qty 10, Total $340.00
#   • Mascarpone Fabioli: Qty 10, Total $320.00
#   • Singaporean Hokkien Fried Mee: Qty 5, Total $70.00
#   • Tofu: Qty 3, Total $69.75
#   • Teatime Chocolate Biscuits: Qty 7, Total $64.40
#   • Konbu: Qty 10, Total $60.00
#   • Outback Lager: Qty 5, Total $60.00
#   • Queso Cabrales: Qty 2, Total $42.00
#   • Gudbrandsdalsost: Qty 1, Total $28.80
#
# ============================================================
# Customer: Antonio Moreno Taquería
# Customer ID: ANTON
# Contact: Antonio Moreno
# Location: México D.F., Mexico
# Total Products Purchased: 15
# Grand Total Spent: $7023.98
# ----------------------------------------
# Products:
#   • Queso Cabrales: Qty 74, Total $1348.20
#   • Perth Pasties: Qty 25, Total $820.00
#   • Gumbär Gummibärchen: Qty 30, Total $796.37
#   • Raclette Courdavault: Qty 15, Total $742.50
#   • Alice Mutton: Qty 18, Total $702.00
#   • Ipoh Coffee: Qty 15, Total $586.50
#   • Sasquatch Ale: Qty 40, Total $560.00
#   • Chang: Qty 20, Total $380.00
#   • Singaporean Hokkien Fried Mee: Qty 20, Total $280.00
#   • Rhönbräu Klosterbier: Qty 30, Total $232.50
#   • Boston Crab Meat: Qty 10, Total $165.60
#   • Chocolade: Qty 15, Total $162.56
#   • Geitost: Qty 38, Total $92.00
#   • Ravioli Angelo: Qty 5, Total $87.75
#   • Louisiana Hot Spiced Okra: Qty 4, Total $68.00
#
# ============================================================
# Customer: Around the Horn
# Customer ID: AROUT
# Contact: Thomas Hardy
# Location: London, UK
# Total Products Purchased: 24
# Grand Total Spent: $13390.65
# ----------------------------------------
# Products:
#   • Sir Rodney's Marmalade: Qty 50, Total $3847.50
#   • Gorgonzola Telino: Qty 115, Total $1406.25
#   • Ravioli Angelo: Qty 65, Total $1170.00
#   • Manjimup Dried Apples: Qty 20, Total $1060.00
#   • Outback Lager: Qty 53, Total $627.00
#   • Gnocchi di nonna Alice: Qty 20, Total $608.00
#   • Perth Pasties: Qty 18, Total $590.40
#   • Valkoinen suklaa: Qty 39, Total $585.00
#   • Camembert Pierrot: Qty 15, Total $510.00
#   • Pâté chinois: Qty 21, Total $504.00
#   • Spegesild: Qty 28, Total $319.20
#   • Inlagd Sill: Qty 16, Total $304.00
#   • Filo Mix: Qty 38, Total $266.00
#   • Flotemysost: Qty 12, Total $258.00
#   • Zaanse koeken: Qty 25, Total $237.50
#   • Chang: Qty 15, Total $228.00
#   • Laughing Lumberjack Lager: Qty 15, Total $210.00
#   • Chocolade: Qty 15, Total $137.70
#   • Jack's New England Clam Chowder: Qty 14, Total $135.10
#   • Konbu: Qty 20, Total $96.00
#   • Guaraná Fantástica: Qty 25, Total $90.00
#   • Gustaf's Knäckebröd: Qty 4, Total $84.00
#   • Steeleye Stout: Qty 4, Total $72.00
#   • Röd Kaviar: Qty 3, Total $45.00
#
# ============================================================
# Customer: B's Beverages
# Customer ID: BSBEV
# Contact: Victoria Ashworth
# Location: London, UK
# Total Products Purchased: 19
# Grand Total Spent: $6089.90
# ----------------------------------------
# Products:
#   • Ipoh Coffee: Qty 30, Total $1380.00
#   • Uncle Bob's Organic Dried Pears: Qty 34, Total $840.00
#   • Gnocchi di nonna Alice: Qty 20, Total $608.00
#   • Tarte au sucre: Qty 10, Total $493.00
#   • Gustaf's Knäckebröd: Qty 21, Total $441.00
#   • Steeleye Stout: Qty 20, Total $360.00
#   • Sir Rodney's Scones: Qty 29, Total $262.00
#   • Aniseed Syrup: Qty 30, Total $240.00
#   • Wimmers gute Semmelknödel: Qty 9, Total $239.40
#   • Raclette Courdavault: Qty 4, Total $220.00
#   • Spegesild: Qty 15, Total $180.00
#   • Boston Crab Meat: Qty 10, Total $147.00
#   • Konbu: Qty 23, Total $138.00
#   • Manjimup Dried Apples: Qty 3, Total $127.20
#   • Maxilaku: Qty 6, Total $120.00
#   • Ravioli Angelo: Qty 6, Total $117.00
#   • Outback Lager: Qty 7, Total $105.00
#   • Geitost: Qty 15, Total $37.50
#   • Mozzarella di Giovanni: Qty 1, Total $34.80
#
# ============================================================
# Customer: Berglunds snabbköp
# Customer ID: BERGS
# Contact: Christina Berglund
# Location: Luleå, Sweden
# Total Products Purchased: 37
# Grand Total Spent: $24927.58
# ----------------------------------------
# Products:
#   • Côte de Blaye: Qty 15, Total $3557.25
#   • Ipoh Coffee: Qty 60, Total $2760.00
#   • Rössle Sauerkraut: Qty 50, Total $2143.20
#   • Sir Rodney's Marmalade: Qty 28, Total $1814.40
#   • Boston Crab Meat: Qty 75, Total $1380.00
#   • Gumbär Gummibärchen: Qty 50, Total $1193.29
#   • Camembert Pierrot: Qty 35, Total $1088.00
#   • Nord-Ost Matjeshering: Qty 50, Total $1035.60
#   • Thüringer Rostbratwurst: Qty 10, Total $928.43
#   • Flotemysost: Qty 32, Total $688.00
#   • Raclette Courdavault: Qty 15, Total $660.00
#   • Ikura: Qty 22, Total $620.00
#   • Chai: Qty 35, Total $472.50
#   • Zaanse koeken: Qty 61, Total $464.55
#   • Chartreuse verte: Qty 26, Total $410.40
#   • Perth Pasties: Qty 12, Total $393.60
#   • Pâté chinois: Qty 20, Total $384.00
#   • Tofu: Qty 16, Total $372.00
#   • Rhönbräu Klosterbier: Qty 51, Total $337.12
#   • Jack's New England Clam Chowder: Qty 40, Total $327.50
#   • Alice Mutton: Qty 10, Total $312.00
#   • Maxilaku: Qty 15, Total $300.00
#   • Röd Kaviar: Qty 25, Total $300.00
#   • Aniseed Syrup: Qty 30, Total $300.00
#   • Chang: Qty 21, Total $299.25
#   • Mascarpone Fabioli: Qty 10, Total $288.00
#   • Lakkalikööri: Qty 21, Total $283.50
#   • Vegie-spread: Qty 8, Total $280.80
#   • Gula Malacca: Qty 16, Total $248.00
#   • Tourtière: Qty 36, Total $240.48
#   • Chef Anton's Cajun Seasoning: Qty 12, Total $237.60
#   • Teatime Chocolate Biscuits: Qty 25, Total $230.00
#   • Pavlova: Qty 12, Total $188.46
#   • Filo Mix: Qty 25, Total $175.00
#   • Steeleye Stout: Qty 8, Total $115.20
#   • Guaraná Fantástica: Qty 18, Total $63.45
#   • Konbu: Qty 6, Total $36.00
#
# ============================================================
# Customer: Blauer See Delikatessen
# Customer ID: BLAUS
# Contact: Hanna Moos
# Location: Mannheim, Germany
# Total Products Purchased: 12
# Grand Total Spent: $3239.80
# ----------------------------------------
# Products:
#   • Camembert Pierrot: Qty 21, Total $714.00
#   • Carnarvon Tigers: Qty 10, Total $625.00
#   • Manjimup Dried Apples: Qty 8, Total $424.00
#   • Queso Cabrales: Qty 14, Total $294.00
#   • Lakkalikööri: Qty 14, Total $252.00
#   • Sir Rodney's Scones: Qty 23, Total $230.00
#   • Tourtière: Qty 20, Total $149.00
#   • Rössle Sauerkraut: Qty 3, Total $136.80
#   • Zaanse koeken: Qty 14, Total $133.00
#   • Sirop d'érable: Qty 4, Total $114.00
#   • Chartreuse verte: Qty 5, Total $90.00
#   • Ravioli Angelo: Qty 4, Total $78.00
#
# ============================================================
# Customer: Blondesddsl père et fils
# Customer ID: BLONP
# Contact: Frédérique Citeaux
# Location: Strasbourg, France
# Total Products Purchased: 25
# Grand Total Spent: $18534.08
# ----------------------------------------
# Products:
#   • Thüringer Rostbratwurst: Qty 35, Total $3465.00
#   • Côte de Blaye: Qty 10, Total $2108.00
#   • Tarte au sucre: Qty 35, Total $1379.00
#   • Gnocchi di nonna Alice: Qty 40, Total $1094.40
#   • Rössle Sauerkraut: Qty 30, Total $1092.00
#   • Gorgonzola Telino: Qty 85, Total $1031.25
#   • Carnarvon Tigers: Qty 18, Total $956.25
#   • Alice Mutton: Qty 30, Total $936.00
#   • Chartreuse verte: Qty 60, Total $864.00
#   • Wimmers gute Semmelknödel: Qty 30, Total $718.20
#   • Raclette Courdavault: Qty 12, Total $660.00
#   • Queso Cabrales: Qty 35, Total $624.75
#   • Maxilaku: Qty 35, Total $560.00
#   • Mozzarella di Giovanni: Qty 20, Total $556.00
#   • Chai: Qty 25, Total $450.00
#   • Pâté chinois: Qty 18, Total $410.40
#   • Ikura: Qty 14, Total $347.20
#   • Ravioli Angelo: Qty 15, Total $292.50
#   • Outback Lager: Qty 20, Total $240.00
#   • Lakkalikööri: Qty 10, Total $180.00
#   • Tourtière: Qty 28, Total $165.20
#   • Rhönbräu Klosterbier: Qty 24, Total $133.92
#   • Filo Mix: Qty 20, Total $112.00
#   • Jack's New England Clam Chowder: Qty 12, Total $110.01
#   • Spegesild: Qty 5, Total $48.00
#
# ============================================================
# Customer: Bon app'
# Customer ID: BONAP
# Contact: Laurence Lebihan
# Location: Marseille, France
# Total Products Purchased: 34
# Grand Total Spent: $21963.25
# ----------------------------------------
# Products:
#   • Carnarvon Tigers: Qty 50, Total $2450.00
#   • Manjimup Dried Apples: Qty 40, Total $1855.00
#   • Grandma's Boysenberry Spread: Qty 70, Total $1562.50
#   • Uncle Bob's Organic Dried Pears: Qty 58, Total $1515.00
#   • Ipoh Coffee: Qty 40, Total $1398.40
#   • Ikura: Qty 36, Total $1116.00
#   • Chef Anton's Cajun Seasoning: Qty 50, Total $935.00
#   • Pavlova: Qty 57, Total $918.74
#   • Wimmers gute Semmelknödel: Qty 28, Total $877.80
#   • Gnocchi di nonna Alice: Qty 30, Total $855.00
#   • Boston Crab Meat: Qty 45, Total $772.80
#   • Gudbrandsdalsost: Qty 25, Total $675.00
#   • Flotemysost: Qty 30, Total $645.00
#   • Tarte au sucre: Qty 14, Total $621.18
#   • Alice Mutton: Qty 16, Total $592.80
#   • Inlagd Sill: Qty 30, Total $570.00
#   • NuNuCa Nuß-Nougat-Creme: Qty 50, Total $560.00
#   • Mozzarella di Giovanni: Qty 16, Total $556.80
#   • Singaporean Hokkien Fried Mee: Qty 30, Total $399.00
#   • Chartreuse verte: Qty 21, Total $378.00
#   • Lakkalikööri: Qty 20, Total $360.00
#   • Tofu: Qty 20, Total $348.75
#   • Northwoods Cranberry Sauce: Qty 10, Total $340.00
#   • Spegesild: Qty 21, Total $252.00
#   • Tourtière: Qty 39, Total $230.10
#   • Zaanse koeken: Qty 30, Total $213.75
#   • Ravioli Angelo: Qty 14, Total $204.75
#   • Louisiana Fiery Hot Pepper Sauce: Qty 10, Total $199.97
#   • Rhönbräu Klosterbier: Qty 20, Total $139.50
#   • Konbu: Qty 20, Total $120.00
#   • Tunnbröd: Qty 15, Total $108.00
#   • Jack's New England Clam Chowder: Qty 12, Total $87.78
#   • Teatime Chocolate Biscuits: Qty 10, Total $69.00
#   • Gorgonzola Telino: Qty 3, Total $35.62
#
# ============================================================
# Customer: Bottom-Dollar Markets
# Customer ID: BOTTM
# Contact: Elizabeth Lincoln
# Location: Tsawassen, Canada
# Total Products Purchased: 27
# Grand Total Spent: $20801.60
# ----------------------------------------
# Products:
#   • Tarte au sucre: Qty 101, Total $4522.48
#   • Camembert Pierrot: Qty 75, Total $2337.50
#   • Alice Mutton: Qty 56, Total $1404.00
#   • Ikura: Qty 46, Total $1326.80
#   • Manjimup Dried Apples: Qty 24, Total $1272.00
#   • Mozzarella di Giovanni: Qty 35, Total $1218.00
#   • Raclette Courdavault: Qty 25, Total $1020.80
#   • Chai: Qty 60, Total $810.00
#   • Gula Malacca: Qty 58, Total $758.58
#   • Gnocchi di nonna Alice: Qty 18, Total $684.00
#   • Northwoods Cranberry Sauce: Qty 16, Total $640.00
#   • NuNuCa Nuß-Nougat-Creme: Qty 60, Total $638.40
#   • Uncle Bob's Organic Dried Pears: Qty 20, Total $600.00
#   • Boston Crab Meat: Qty 50, Total $551.25
#   • Scottish Longbreads: Qty 42, Total $525.00
#   • Ipoh Coffee: Qty 9, Total $414.00
#   • Outback Lager: Qty 30, Total $360.00
#   • Grandma's Boysenberry Spread: Qty 12, Total $300.00
#   • Pâté chinois: Qty 15, Total $288.00
#   • Singaporean Hokkien Fried Mee: Qty 20, Total $212.80
#   • Aniseed Syrup: Qty 20, Total $200.00
#   • Zaanse koeken: Qty 30, Total $171.00
#   • Jack's New England Clam Chowder: Qty 25, Total $154.00
#   • Geitost: Qty 64, Total $135.50
#   • Guaraná Fantástica: Qty 30, Total $101.25
#   • Queso Cabrales: Qty 5, Total $78.75
#   • Rhönbräu Klosterbier: Qty 10, Total $77.50
#
# ============================================================
# Customer: Bólido Comidas preparadas
# Customer ID: BOLID
# Contact: Martín Sommer
# Location: Madrid, Spain
# Total Products Purchased: 6
# Grand Total Spent: $4232.85
# ----------------------------------------
# Products:
#   • Thüringer Rostbratwurst: Qty 20, Total $1856.85
#   • Alice Mutton: Qty 40, Total $1170.00
#   • Chef Anton's Cajun Seasoning: Qty 24, Total $422.40
#   • Rhönbräu Klosterbier: Qty 50, Total $310.00
#   • Ravioli Angelo: Qty 16, Total $249.60
#   • Filo Mix: Qty 40, Total $224.00
#
# ============================================================
# Customer: Cactus Comidas para llevar
# Customer ID: CACTU
# Contact: Patricio Simpson
# Location: Buenos Aires, Argentina
# Total Products Purchased: 11
# Grand Total Spent: $1814.80
# ----------------------------------------
# Products:
#   • Rössle Sauerkraut: Qty 8, Total $364.80
#   • Ipoh Coffee: Qty 7, Total $322.00
#   • Laughing Lumberjack Lager: Qty 20, Total $280.00
#   • Sasquatch Ale: Qty 20, Total $280.00
#   • Rhönbräu Klosterbier: Qty 20, Total $155.00
#   • Röd Kaviar: Qty 10, Total $150.00
#   • Jack's New England Clam Chowder: Qty 10, Total $96.50
#   • Scottish Longbreads: Qty 6, Total $75.00
#   • Steeleye Stout: Qty 3, Total $54.00
#   • Geitost: Qty 10, Total $25.00
#   • Gorgonzola Telino: Qty 1, Total $12.50
#
# ============================================================
# Customer: Centro comercial Moctezuma
# Customer ID: CENTC
# Contact: Francisco Chang
# Location: México D.F., Mexico
# Total Products Purchased: 2
# Grand Total Spent: $100.80
# ----------------------------------------
# Products:
#   • Sir Rodney's Scones: Qty 10, Total $80.00
#   • Gravad lax: Qty 1, Total $20.80
#
# ============================================================
# Customer: Chop-suey Chinese
# Customer ID: CHOPS
# Contact: Yang Wang
# Location: Bern, Switzerland
# Total Products Purchased: 17
# Grand Total Spent: $12348.88
# ----------------------------------------
# Products:
#   • Gnocchi di nonna Alice: Qty 72, Total $2667.60
#   • Vegie-spread: Qty 42, Total $1843.80
#   • Manjimup Dried Apples: Qty 30, Total $1510.50
#   • Gudbrandsdalsost: Qty 40, Total $1440.00
#   • Tarte au sucre: Qty 21, Total $946.56
#   • Wimmers gute Semmelknödel: Qty 30, Total $798.00
#   • Ikura: Qty 16, Total $471.20
#   • Chang: Qty 30, Total $456.00
#   • Singaporean Hokkien Fried Mee: Qty 28, Total $392.00
#   • Sir Rodney's Scones: Qty 40, Total $380.00
#   • Pâté chinois: Qty 21, Total $342.72
#   • Camembert Pierrot: Qty 10, Total $323.00
#   • Longlife Tofu: Qty 41, Total $304.00
#   • Gravad lax: Qty 8, Total $208.00
#   • Chai: Qty 15, Total $183.60
#   • Guaraná Fantástica: Qty 15, Total $45.90
#   • Konbu: Qty 6, Total $36.00
#
# ============================================================
# Customer: Comércio Mineiro
# Customer ID: COMMI
# Contact: Pedro Afonso
# Location: Sao Paulo, Brazil
# Total Products Purchased: 9
# Grand Total Spent: $3810.75
# ----------------------------------------
# Products:
#   • Thüringer Rostbratwurst: Qty 15, Total $1485.00
#   • Gnocchi di nonna Alice: Qty 30, Total $912.00
#   • Chef Anton's Gumbo Mix: Qty 20, Total $340.00
#   • Gula Malacca: Qty 15, Total $291.75
#   • Maxilaku: Qty 15, Total $240.00
#   • Queso Cabrales: Qty 10, Total $168.00
#   • Spegesild: Qty 14, Total $156.00
#   • Sirop d'érable: Qty 4, Total $114.00
#   • Original Frankfurter grüne Soße: Qty 10, Total $104.00
#
# ============================================================
# Customer: Consolidated Holdings
# Customer ID: CONSH
# Contact: Elizabeth Brown
# Location: London, UK
# Total Products Purchased: 7
# Grand Total Spent: $1719.10
# ----------------------------------------
# Products:
#   • Chef Anton's Gumbo Mix: Qty 30, Total $640.50
#   • Mishi Kobe Niku: Qty 3, Total $291.00
#   • Mozzarella di Giovanni: Qty 10, Total $278.00
#   • Gustaf's Knäckebröd: Qty 12, Total $201.60
#   • Chang: Qty 10, Total $152.00
#   • Tunnbröd: Qty 21, Total $151.20
#   • Konbu: Qty 1, Total $4.80
#
# ============================================================
# Customer: Die Wandernde Kuh
# Customer ID: WANDK
# Contact: Rita Müller
# Location: Stuttgart, Germany
# Total Products Purchased: 22
# Grand Total Spent: $9588.42
# ----------------------------------------
# Products:
#   • Mascarpone Fabioli: Qty 65, Total $1736.00
#   • Gudbrandsdalsost: Qty 40, Total $1116.00
#   • Ipoh Coffee: Qty 24, Total $883.20
#   • Queso Manchego La Pastora: Qty 20, Total $722.00
#   • Gnocchi di nonna Alice: Qty 20, Total $608.00
#   • Chang: Qty 30, Total $541.50
#   • Perth Pasties: Qty 20, Total $524.00
#   • Wimmers gute Semmelknödel: Qty 15, Total $448.88
#   • Gorgonzola Telino: Qty 38, Total $390.00
#   • Sirop d'érable: Qty 15, Total $342.00
#   • Sir Rodney's Scones: Qty 40, Total $320.00
#   • Pâté chinois: Qty 16, Total $316.80
#   • Gustaf's Knäckebröd: Qty 20, Total $315.00
#   • Steeleye Stout: Qty 18, Total $307.80
#   • Chai: Qty 15, Total $183.60
#   • Tunnbröd: Qty 25, Total $180.00
#   • Outback Lager: Qty 15, Total $168.75
#   • Boston Crab Meat: Qty 10, Total $147.00
#   • Rössle Sauerkraut: Qty 4, Total $145.60
#   • Teatime Chocolate Biscuits: Qty 12, Total $82.80
#   • Rhönbräu Klosterbier: Qty 10, Total $62.00
#   • Geitost: Qty 20, Total $47.50
#
# ============================================================
# Customer: Drachenblut Delikatessen
# Customer ID: DRACD
# Contact: Sven Ottlieb
# Location: Aachen, Germany
# Total Products Purchased: 9
# Grand Total Spent: $3763.21
# ----------------------------------------
# Products:
#   • Raclette Courdavault: Qty 30, Total $1650.00
#   • Perth Pasties: Qty 20, Total $656.00
#   • Queso Cabrales: Qty 20, Total $420.00
#   • Gumbär Gummibärchen: Qty 12, Total $374.76
#   • Gorgonzola Telino: Qty 20, Total $200.00
#   • Lakkalikööri: Qty 12, Total $172.80
#   • Konbu: Qty 25, Total $128.40
#   • Jack's New England Clam Chowder: Qty 9, Total $86.85
#   • Rhönbräu Klosterbier: Qty 12, Total $74.40
#
# ============================================================
# Customer: Du monde entier
# Customer ID: DUMON
# Contact: Janine Labrune
# Location: Nantes, France
# Total Products Purchased: 9
# Grand Total Spent: $1615.90
# ----------------------------------------
# Products:
#   • Alice Mutton: Qty 15, Total $585.00
#   • Ikura: Qty 10, Total $310.00
#   • Gudbrandsdalsost: Qty 7, Total $201.60
#   • Sasquatch Ale: Qty 10, Total $140.00
#   • Jack's New England Clam Chowder: Qty 14, Total $135.10
#   • Singaporean Hokkien Fried Mee: Qty 6, Total $67.20
#   • Filo Mix: Qty 9, Total $63.00
#   • Sir Rodney's Scones: Qty 6, Total $60.00
#   • Chai: Qty 3, Total $54.00
#
# ============================================================
# Customer: Eastern Connection
# Customer ID: EASTC
# Contact: Ann Devon
# Location: London, UK
# Total Products Purchased: 19
# Grand Total Spent: $14761.03
# ----------------------------------------
# Products:
#   • Uncle Bob's Organic Dried Pears: Qty 100, Total $3000.00
#   • Thüringer Rostbratwurst: Qty 21, Total $2079.00
#   • Camembert Pierrot: Qty 50, Total $1700.00
#   • Flotemysost: Qty 55, Total $1161.00
#   • Gudbrandsdalsost: Qty 30, Total $864.00
#   • Pâté chinois: Qty 35, Total $840.00
#   • Mozzarella di Giovanni: Qty 20, Total $696.00
#   • Chef Anton's Cajun Seasoning: Qty 25, Total $550.00
#   • Steeleye Stout: Qty 35, Total $504.00
#   • Chef Anton's Gumbo Mix: Qty 30, Total $480.38
#   • Maxilaku: Qty 30, Total $480.00
#   • Louisiana Fiery Hot Pepper Sauce: Qty 21, Total $442.05
#   • Louisiana Hot Spiced Okra: Qty 24, Total $408.00
#   • Nord-Ost Matjeshering: Qty 15, Total $388.35
#   • Gumbär Gummibärchen: Qty 12, Total $374.76
#   • Chai: Qty 25, Total $337.50
#   • Ipoh Coffee: Qty 6, Total $276.00
#   • Queso Cabrales: Qty 5, Total $105.00
#   • Geitost: Qty 30, Total $75.00
#
# ============================================================
# Customer: Ernst Handel
# Customer ID: ERNSH
# Contact: Roland Mendel
# Location: Graz, Austria
# Total Products Purchased: 56
# Grand Total Spent: $104874.98
# ----------------------------------------
# Products:
#   • Raclette Courdavault: Qty 180, Total $8514.00
#   • Wimmers gute Semmelknödel: Qty 199, Total $6290.90
#   • Manjimup Dried Apples: Qty 120, Total $6042.00
#   • Camembert Pierrot: Qty 160, Total $5440.00
#   • Rössle Sauerkraut: Qty 118, Total $5054.28
#   • Sirop d'érable: Qty 186, Total $4163.85
#   • Côte de Blaye: Qty 20, Total $4005.20
#   • Vegie-spread: Qty 100, Total $3818.00
#   • Alice Mutton: Qty 121, Total $3730.35
#   • Gnocchi di nonna Alice: Qty 100, Total $3572.00
#   • Tarte au sucre: Qty 80, Total $3352.40
#   • Sir Rodney's Marmalade: Qty 39, Total $3159.00
#   • Queso Manchego La Pastora: Qty 86, Total $3062.80
#   • Gudbrandsdalsost: Qty 110, Total $3051.00
#   • Chartreuse verte: Qty 175, Total $2916.00
#   • Thüringer Rostbratwurst: Qty 26, Total $2797.21
#   • Ikura: Qty 100, Total $2635.00
#   • Louisiana Fiery Hot Pepper Sauce: Qty 114, Total $2280.39
#   • Pavlova: Qty 146, Total $2007.87
#   • Sasquatch Ale: Qty 150, Total $1911.00
#   • Gorgonzola Telino: Qty 170, Total $1730.00
#   • Boston Crab Meat: Qty 91, Total $1674.40
#   • Chef Anton's Gumbo Mix: Qty 97, Total $1428.00
#   • Pâté chinois: Qty 65, Total $1326.00
#   • Schoggi Schokolade: Qty 30, Total $1317.00
#   • Gula Malacca: Qty 77, Total $1133.83
#   • Gustaf's Knäckebröd: Qty 52, Total $1092.00
#   • Guaraná Fantástica: Qty 248, Total $1090.80
#   • Sir Rodney's Scones: Qty 120, Total $1086.00
#   • Flotemysost: Qty 51, Total $1036.30
#   • Steeleye Stout: Qty 76, Total $1031.40
#   • Nord-Ost Matjeshering: Qty 60, Total $931.50
#   • Gumbär Gummibärchen: Qty 35, Total $929.09
#   • Ravioli Angelo: Qty 49, Total $858.00
#   • Queso Cabrales: Qty 45, Total $819.00
#   • Louisiana Hot Spiced Okra: Qty 60, Total $816.00
#   • Chang: Qty 58, Total $760.00
#   • Longlife Tofu: Qty 86, Total $616.00
#   • Chocolade: Qty 70, Total $606.90
#   • Mozzarella di Giovanni: Qty 24, Total $600.48
#   • Outback Lager: Qty 38, Total $564.00
#   • Uncle Bob's Organic Dried Pears: Qty 18, Total $540.00
#   • Singaporean Hokkien Fried Mee: Qty 40, Total $492.80
#   • Jack's New England Clam Chowder: Qty 53, Total $486.10
#   • Tourtière: Qty 80, Total $472.00
#   • Carnarvon Tigers: Qty 9, Total $450.00
#   • Tunnbröd: Qty 60, Total $432.00
#   • Spegesild: Qty 45, Total $432.00
#   • Rhönbräu Klosterbier: Qty 57, Total $430.90
#   • Aniseed Syrup: Qty 45, Total $430.00
#   • Konbu: Qty 78, Total $397.80
#   • Valkoinen suklaa: Qty 22, Total $357.50
#   • Rogede sild: Qty 27, Total $243.67
#   • Tofu: Qty 11, Total $217.39
#   • Mascarpone Fabioli: Qty 6, Total $122.88
#   • Geitost: Qty 60, Total $120.00
#
# ============================================================
# Customer: Familia Arquibaldo
# Customer ID: FAMIA
# Contact: Aria Cruz
# Location: Sao Paulo, Brazil
# Total Products Purchased: 17
# Grand Total Spent: $4107.55
# ----------------------------------------
# Products:
#   • Perth Pasties: Qty 25, Total $779.00
#   • Nord-Ost Matjeshering: Qty 30, Total $776.70
#   • Chartreuse verte: Qty 50, Total $612.00
#   • Camembert Pierrot: Qty 12, Total $346.80
#   • Rhönbräu Klosterbier: Qty 56, Total $341.62
#   • Tourtière: Qty 30, Total $223.50
#   • Pâté chinois: Qty 6, Total $144.00
#   • Teatime Chocolate Biscuits: Qty 18, Total $124.83
#   • Jack's New England Clam Chowder: Qty 12, Total $115.80
#   • Sasquatch Ale: Qty 10, Total $112.00
#   • NuNuCa Nuß-Nougat-Creme: Qty 10, Total $112.00
#   • Geitost: Qty 50, Total $100.00
#   • Guaraná Fantástica: Qty 25, Total $92.25
#   • Spegesild: Qty 9, Total $91.80
#   • Boston Crab Meat: Qty 4, Total $58.80
#   • Zaanse koeken: Qty 6, Total $48.45
#   • Filo Mix: Qty 4, Total $28.00
#
# ============================================================
# Customer: Folies gourmandes
# Customer ID: FOLIG
# Contact: Martine Rancé
# Location: Lille, France
# Total Products Purchased: 15
# Grand Total Spent: $11666.90
# ----------------------------------------
# Products:
#   • Carnarvon Tigers: Qty 80, Total $5000.00
#   • Tarte au sucre: Qty 35, Total $1379.00
#   • Vegie-spread: Qty 30, Total $1317.00
#   • Uncle Bob's Organic Dried Pears: Qty 35, Total $1050.00
#   • Manjimup Dried Apples: Qty 15, Total $795.00
#   • Raclette Courdavault: Qty 12, Total $528.00
#   • Sir Rodney's Scones: Qty 40, Total $400.00
#   • Steeleye Stout: Qty 15, Total $270.00
#   • Zaanse koeken: Qty 30, Total $228.00
#   • Scottish Longbreads: Qty 18, Total $225.00
#   • Gravad lax: Qty 10, Total $208.00
#   • Gustaf's Knäckebröd: Qty 6, Total $126.00
#   • Guaraná Fantástica: Qty 20, Total $90.00
#   • Tourtière: Qty 6, Total $35.40
#   • Rhönbräu Klosterbier: Qty 2, Total $15.50
#
# ============================================================
# Customer: Folk och fä HB
# Customer ID: FOLKO
# Contact: Maria Larsson
# Location: Bräcke, Sweden
# Total Products Purchased: 30
# Grand Total Spent: $29567.56
# ----------------------------------------
# Products:
#   • Manjimup Dried Apples: Qty 88, Total $4664.00
#   • Thüringer Rostbratwurst: Qty 50, Total $4642.12
#   • Gnocchi di nonna Alice: Qty 60, Total $2280.00
#   • Raclette Courdavault: Qty 35, Total $1925.00
#   • Uncle Bob's Organic Dried Pears: Qty 60, Total $1800.00
#   • Chef Anton's Cajun Seasoning: Qty 50, Total $1045.00
#   • Lakkalikööri: Qty 68, Total $1030.32
#   • Chang: Qty 65, Total $931.00
#   • Vegie-spread: Qty 20, Total $878.00
#   • Röd Kaviar: Qty 59, Total $867.00
#   • Louisiana Hot Spiced Okra: Qty 50, Total $850.00
#   • Mozzarella di Giovanni: Qty 24, Total $835.20
#   • Chartreuse verte: Qty 46, Total $828.00
#   • Queso Cabrales: Qty 56, Total $772.80
#   • Pâté chinois: Qty 36, Total $756.00
#   • Outback Lager: Qty 59, Total $735.00
#   • Sirop d'érable: Qty 30, Total $684.00
#   • Nord-Ost Matjeshering: Qty 35, Total $579.60
#   • Zaanse koeken: Qty 60, Total $570.00
#   • Jack's New England Clam Chowder: Qty 72, Total $532.74
#   • Gustaf's Knäckebröd: Qty 25, Total $525.00
#   • Rhönbräu Klosterbier: Qty 56, Total $341.00
#   • Spegesild: Qty 25, Total $300.00
#   • Escargots de Bourgogne: Qty 30, Total $254.40
#   • Tarte au sucre: Qty 6, Total $251.43
#   • Tunnbröd: Qty 30, Total $216.00
#   • Gula Malacca: Qty 10, Total $194.50
#   • Scottish Longbreads: Qty 21, Total $157.50
#   • Flotemysost: Qty 6, Total $103.20
#   • Gorgonzola Telino: Qty 2, Total $18.75
#
# ============================================================
# Customer: France restauration
# Customer ID: FRANR
# Contact: Carine Schmitt
# Location: Nantes, France
# Total Products Purchased: 6
# Grand Total Spent: $3172.16
# ----------------------------------------
# Products:
#   • Thüringer Rostbratwurst: Qty 14, Total $1733.06
#   • Tarte au sucre: Qty 10, Total $493.00
#   • Lakkalikööri: Qty 20, Total $360.00
#   • Louisiana Fiery Hot Pepper Sauce: Qty 12, Total $252.60
#   • Pavlova: Qty 10, Total $174.50
#   • Manjimup Dried Apples: Qty 3, Total $159.00
#
# ============================================================
# Customer: Franchi S.p.A.
# Customer ID: FRANS
# Contact: Paolo Accorti
# Location: Torino, Italy
# Total Products Purchased: 10
# Grand Total Spent: $1545.70
# ----------------------------------------
# Products:
#   • Manjimup Dried Apples: Qty 10, Total $530.00
#   • Carnarvon Tigers: Qty 8, Total $500.00
#   • Camembert Pierrot: Qty 4, Total $136.00
#   • Original Frankfurter grüne Soße: Qty 10, Total $130.00
#   • Longlife Tofu: Qty 5, Total $50.00
#   • Gumbär Gummibärchen: Qty 2, Total $49.80
#   • Zaanse koeken: Qty 5, Total $47.50
#   • Teatime Chocolate Biscuits: Qty 5, Total $46.00
#   • Rogede sild: Qty 4, Total $38.00
#   • Boston Crab Meat: Qty 1, Total $18.40
#
# ============================================================
# Customer: Frankenversand
# Customer ID: FRANK
# Contact: Peter Franken
# Location: München, Germany
# Total Products Purchased: 33
# Grand Total Spent: $26656.56
# ----------------------------------------
# Products:
#   • Raclette Courdavault: Qty 100, Total $3938.00
#   • Flotemysost: Qty 120, Total $2257.50
#   • Camembert Pierrot: Qty 56, Total $1774.80
#   • Thüringer Rostbratwurst: Qty 14, Total $1646.41
#   • Mozzarella di Giovanni: Qty 46, Total $1278.80
#   • Tofu: Qty 51, Total $1185.75
#   • Sir Rodney's Scones: Qty 117, Total $1129.00
#   • Röd Kaviar: Qty 70, Total $942.00
#   • Tunnbröd: Qty 112, Total $864.00
#   • Gudbrandsdalsost: Qty 25, Total $855.00
#   • Inlagd Sill: Qty 60, Total $790.40
#   • Wimmers gute Semmelknödel: Qty 30, Total $748.12
#   • Boston Crab Meat: Qty 50, Total $735.00
#   • Spegesild: Qty 60, Total $720.00
#   • Pâté chinois: Qty 40, Total $614.40
#   • Gumbär Gummibärchen: Qty 24, Total $597.60
#   • Gravad lax: Qty 28, Total $582.40
#   • Rhönbräu Klosterbier: Qty 74, Total $573.50
#   • Teatime Chocolate Biscuits: Qty 65, Total $561.20
#   • Tarte au sucre: Qty 15, Total $554.62
#   • Nord-Ost Matjeshering: Qty 20, Total $517.80
#   • Steeleye Stout: Qty 30, Total $486.00
#   • Pavlova: Qty 30, Total $471.15
#   • Gorgonzola Telino: Qty 56, Total $448.00
#   • Escargots de Bourgogne: Qty 30, Total $397.50
#   • Laughing Lumberjack Lager: Qty 25, Total $350.00
#   • Perth Pasties: Qty 10, Total $328.00
#   • Tourtière: Qty 50, Total $307.31
#   • Chang: Qty 24, Total $291.84
#   • Original Frankfurter grüne Soße: Qty 15, Total $195.00
#   • Lakkalikööri: Qty 15, Total $183.60
#   • Jack's New England Clam Chowder: Qty 20, Total $183.35
#   • Guaraná Fantástica: Qty 43, Total $148.50
#
# ============================================================
# Customer: Furia Bacalhau e Frutos do Mar
# Customer ID: FURIB
# Contact: Lino Rodriguez
# Location: Lisboa, Portugal
# Total Products Purchased: 16
# Grand Total Spent: $6427.42
# ----------------------------------------
# Products:
#   • Gnocchi di nonna Alice: Qty 42, Total $1117.20
#   • Gula Malacca: Qty 55, Total $975.62
#   • Louisiana Fiery Hot Pepper Sauce: Qty 55, Total $940.39
#   • Ikura: Qty 24, Total $632.40
#   • Camembert Pierrot: Qty 22, Total $601.80
#   • Pavlova: Qty 40, Total $593.30
#   • Raclette Courdavault: Qty 9, Total $396.00
#   • Steeleye Stout: Qty 20, Total $306.00
#   • Chef Anton's Cajun Seasoning: Qty 16, Total $225.28
#   • Lakkalikööri: Qty 10, Total $162.00
#   • Ipoh Coffee: Qty 3, Total $110.40
#   • Tourtière: Qty 20, Total $100.30
#   • Scottish Longbreads: Qty 10, Total $100.00
#   • Chocolade: Qty 6, Total $68.85
#   • Original Frankfurter grüne Soße: Qty 7, Total $61.88
#   • Guaraná Fantástica: Qty 10, Total $36.00
#
# ============================================================
# Customer: GROSELLA-Restaurante
# Customer ID: GROSR
# Contact: Manuel Pereira
# Location: Caracas, Venezuela
# Total Products Purchased: 4
# Grand Total Spent: $1488.70
# ----------------------------------------
# Products:
#   • Thüringer Rostbratwurst: Qty 10, Total $990.00
#   • Ikura: Qty 10, Total $310.00
#   • Mozzarella di Giovanni: Qty 4, Total $111.20
#   • Rhönbräu Klosterbier: Qty 10, Total $77.50
#
# ============================================================
# Customer: Galería del gastrónomo
# Customer ID: GALED
# Contact: Eduardo Saavedra
# Location: Barcelona, Spain
# Total Products Purchased: 8
# Grand Total Spent: $836.70
# ----------------------------------------
# Products:
#   • Wimmers gute Semmelknödel: Qty 7, Total $186.20
#   • Ikura: Qty 5, Total $155.00
#   • Gnocchi di nonna Alice: Qty 5, Total $152.00
#   • Lakkalikööri: Qty 5, Total $90.00
#   • Louisiana Fiery Hot Pepper Sauce: Qty 5, Total $84.00
#   • NuNuCa Nuß-Nougat-Creme: Qty 5, Total $70.00
#   • Original Frankfurter grüne Soße: Qty 5, Total $52.00
#   • Zaanse koeken: Qty 5, Total $47.50
#
# ============================================================
# Customer: Godos Cocina Típica
# Customer ID: GODOS
# Contact: José Pedro Freyre
# Location: Sevilla, Spain
# Total Products Purchased: 21
# Grand Total Spent: $11446.36
# ----------------------------------------
# Products:
#   • Thüringer Rostbratwurst: Qty 20, Total $2475.80
#   • Manjimup Dried Apples: Qty 40, Total $2120.00
#   • Tarte au sucre: Qty 20, Total $936.70
#   • Louisiana Fiery Hot Pepper Sauce: Qty 51, Total $873.55
#   • Wimmers gute Semmelknödel: Qty 24, Total $773.06
#   • Alice Mutton: Qty 20, Total $748.80
#   • Boston Crab Meat: Qty 40, Total $529.20
#   • Chang: Qty 20, Total $380.00
#   • Scottish Longbreads: Qty 33, Total $360.00
#   • Pâté chinois: Qty 14, Total $324.00
#   • Ikura: Qty 10, Total $310.00
#   • Camembert Pierrot: Qty 9, Total $306.00
#   • Inlagd Sill: Qty 18, Total $256.50
#   • Sirop d'érable: Qty 10, Total $256.50
#   • Laughing Lumberjack Lager: Qty 15, Total $210.00
#   • Chai: Qty 10, Total $180.00
#   • Valkoinen suklaa: Qty 9, Total $146.25
#   • Teatime Chocolate Biscuits: Qty 10, Total $92.00
#   • Outback Lager: Qty 4, Total $60.00
#   • Guaraná Fantástica: Qty 12, Total $54.00
#   • Sir Rodney's Scones: Qty 6, Total $54.00
#
# ============================================================
# Customer: Gourmet Lanchonetes
# Customer ID: GOURL
# Contact: André Fonseca
# Location: Campinas, Brazil
# Total Products Purchased: 17
# Grand Total Spent: $8414.14
# ----------------------------------------
# Products:
#   • Northwoods Cranberry Sauce: Qty 40, Total $1600.00
#   • Manjimup Dried Apples: Qty 28, Total $1484.00
#   • Raclette Courdavault: Qty 20, Total $880.00
#   • Grandma's Boysenberry Spread: Qty 30, Total $750.00
#   • Gnocchi di nonna Alice: Qty 20, Total $646.00
#   • Ikura: Qty 20, Total $620.00
#   • Singaporean Hokkien Fried Mee: Qty 40, Total $504.00
#   • Nord-Ost Matjeshering: Qty 17, Total $427.19
#   • Lakkalikööri: Qty 20, Total $360.00
#   • Camembert Pierrot: Qty 10, Total $340.00
#   • Chang: Qty 10, Total $152.00
#   • Zaanse koeken: Qty 15, Total $142.50
#   • Gorgonzola Telino: Qty 14, Total $140.00
#   • Rhönbräu Klosterbier: Qty 20, Total $131.75
#   • Queso Manchego La Pastora: Qty 4, Total $121.60
#   • Uncle Bob's Organic Dried Pears: Qty 3, Total $76.50
#   • Jack's New England Clam Chowder: Qty 4, Total $38.60
#
# ============================================================
# Customer: Great Lakes Food Market
# Customer ID: GREAL
# Contact: Howard Snyder
# Location: Eugene, USA
# Total Products Purchased: 20
# Grand Total Spent: $18507.45
# ----------------------------------------
# Products:
#   • Côte de Blaye: Qty 45, Total $11264.62
#   • Raclette Courdavault: Qty 30, Total $1402.50
#   • Tarte au sucre: Qty 20, Total $936.70
#   • Wimmers gute Semmelknödel: Qty 28, Total $931.00
#   • Gnocchi di nonna Alice: Qty 14, Total $532.00
#   • Camembert Pierrot: Qty 15, Total $510.00
#   • Gula Malacca: Qty 28, Total $490.14
#   • Inlagd Sill: Qty 30, Total $456.00
#   • Mozzarella di Giovanni: Qty 9, Total $313.20
#   • Sir Rodney's Scones: Qty 32, Total $308.00
#   • Flotemysost: Qty 15, Total $306.38
#   • Teatime Chocolate Biscuits: Qty 30, Total $248.40
#   • Outback Lager: Qty 15, Total $213.75
#   • Thüringer Rostbratwurst: Qty 2, Total $185.69
#   • Chai: Qty 8, Total $144.00
#   • Steeleye Stout: Qty 4, Total $72.00
#   • Queso Cabrales: Qty 3, Total $63.00
#   • Tofu: Qty 3, Total $62.77
#   • Zaanse koeken: Qty 6, Total $51.30
#   • Geitost: Qty 8, Total $16.00
#
# ============================================================
# Customer: HILARION-Abastos
# Customer ID: HILAA
# Contact: Carlos Hernández
# Location: San Cristóbal, Venezuela
# Total Products Purchased: 33
# Grand Total Spent: $22768.76
# ----------------------------------------
# Products:
#   • Raclette Courdavault: Qty 95, Total $4565.00
#   • Manjimup Dried Apples: Qty 45, Total $2120.00
#   • Perth Pasties: Qty 70, Total $1650.60
#   • Gudbrandsdalsost: Qty 50, Total $1569.60
#   • Wimmers gute Semmelknödel: Qty 43, Total $1197.00
#   • Boston Crab Meat: Qty 65, Total $1196.00
#   • Chang: Qty 50, Total $950.00
#   • Rössle Sauerkraut: Qty 20, Total $912.00
#   • Schoggi Schokolade: Qty 25, Total $877.50
#   • Nord-Ost Matjeshering: Qty 30, Total $776.70
#   • Rhönbräu Klosterbier: Qty 106, Total $765.70
#   • Steeleye Stout: Qty 40, Total $720.00
#   • Flotemysost: Qty 30, Total $645.00
#   • Gumbär Gummibärchen: Qty 21, Total $524.66
#   • Jack's New England Clam Chowder: Qty 54, Total $521.10
#   • Singaporean Hokkien Fried Mee: Qty 30, Total $420.00
#   • Konbu: Qty 68, Total $403.20
#   • Ravioli Angelo: Qty 20, Total $390.00
#   • Chai: Qty 20, Total $306.00
#   • Scottish Longbreads: Qty 30, Total $300.00
#   • Gorgonzola Telino: Qty 20, Total $250.00
#   • Spegesild: Qty 28, Total $241.92
#   • NuNuCa Nuß-Nougat-Creme: Qty 15, Total $210.00
#   • Gula Malacca: Qty 10, Total $194.50
#   • Guaraná Fantástica: Qty 39, Total $164.25
#   • Original Frankfurter grüne Soße: Qty 15, Total $156.00
#   • Outback Lager: Qty 12, Total $144.00
#   • Escargots de Bourgogne: Qty 12, Total $135.15
#   • Mascarpone Fabioli: Qty 4, Total $128.00
#   • Longlife Tofu: Qty 16, Total $128.00
#   • Chartreuse verte: Qty 6, Total $86.40
#   • Queso Cabrales: Qty 5, Total $84.00
#   • Pâté chinois: Qty 2, Total $36.48
#
# ============================================================
# Customer: Hanari Carnes
# Customer ID: HANAR
# Contact: Mario Pontes
# Location: Rio de Janeiro, Brazil
# Total Products Purchased: 23
# Grand Total Spent: $32841.37
# ----------------------------------------
# Products:
#   • Côte de Blaye: Qty 69, Total $18076.10
#   • Ikura: Qty 70, Total $2170.00
#   • Louisiana Fiery Hot Pepper Sauce: Qty 72, Total $1338.27
#   • Manjimup Dried Apples: Qty 35, Total $1261.40
#   • Carnarvon Tigers: Qty 20, Total $1250.00
#   • Ipoh Coffee: Qty 30, Total $1104.00
#   • Gudbrandsdalsost: Qty 30, Total $1080.00
#   • Original Frankfurter grüne Soße: Qty 70, Total $812.50
#   • Gorgonzola Telino: Qty 65, Total $762.50
#   • Inlagd Sill: Qty 40, Total $688.75
#   • Maxilaku: Qty 40, Total $640.00
#   • Chartreuse verte: Qty 42, Total $604.80
#   • Alice Mutton: Qty 15, Total $585.00
#   • Gnocchi di nonna Alice: Qty 20, Total $570.00
#   • Teatime Chocolate Biscuits: Qty 35, Total $322.00
#   • Guaraná Fantástica: Qty 70, Total $299.25
#   • Scottish Longbreads: Qty 20, Total $250.00
#   • Konbu: Qty 40, Total $240.00
#   • Queso Cabrales: Qty 15, Total $236.25
#   • Sirop d'érable: Qty 10, Total $228.00
#   • Flotemysost: Qty 9, Total $174.15
#   • Jack's New England Clam Chowder: Qty 10, Total $77.00
#   • Filo Mix: Qty 12, Total $71.40
#
# ============================================================
# Customer: Hungry Coyote Import Store
# Customer ID: HUNGC
# Contact: Yoshi Latimer
# Location: Elgin, USA
# Total Products Purchased: 8
# Grand Total Spent: $3063.20
# ----------------------------------------
# Products:
#   • Sir Rodney's Marmalade: Qty 21, Total $1701.00
#   • Röd Kaviar: Qty 30, Total $450.00
#   • Tarte au sucre: Qty 10, Total $394.00
#   • Tofu: Qty 15, Total $279.00
#   • Tourtière: Qty 14, Total $88.80
#   • Alice Mutton: Qty 2, Total $62.40
#   • Konbu: Qty 10, Total $48.00
#   • Geitost: Qty 20, Total $40.00
#
# ============================================================
# Customer: Hungry Owl All-Night Grocers
# Customer ID: HUNGO
# Contact: Patricia McKenna
# Location: Cork, Ireland
# Total Products Purchased: 36
# Grand Total Spent: $49979.90
# ----------------------------------------
# Products:
#   • Thüringer Rostbratwurst: Qty 150, Total $16711.65
#   • Raclette Courdavault: Qty 112, Total $4713.50
#   • Mishi Kobe Niku: Qty 50, Total $3637.50
#   • Carnarvon Tigers: Qty 33, Total $1856.25
#   • Manjimup Dried Apples: Qty 51, Total $1787.16
#   • Tofu: Qty 70, Total $1627.50
#   • Flotemysost: Qty 103, Total $1588.85
#   • Nord-Ost Matjeshering: Qty 54, Total $1267.38
#   • Louisiana Fiery Hot Pepper Sauce: Qty 60, Total $1263.00
#   • Escargots de Bourgogne: Qty 129, Total $1197.80
#   • Gnocchi di nonna Alice: Qty 30, Total $1140.00
#   • Mascarpone Fabioli: Qty 41, Total $1130.88
#   • Jack's New England Clam Chowder: Qty 110, Total $955.35
#   • Vegie-spread: Qty 35, Total $921.38
#   • Gorgonzola Telino: Qty 85, Total $800.00
#   • Ipoh Coffee: Qty 20, Total $736.00
#   • Chang: Qty 47, Total $693.12
#   • Boston Crab Meat: Qty 40, Total $662.40
#   • Queso Cabrales: Qty 40, Total $630.00
#   • Grandma's Boysenberry Spread: Qty 30, Total $600.00
#   • Tarte au sucre: Qty 15, Total $591.00
#   • Pavlova: Qty 36, Total $565.38
#   • Perth Pasties: Qty 23, Total $565.08
#   • Inlagd Sill: Qty 46, Total $541.50
#   • Lakkalikööri: Qty 35, Total $535.50
#   • Valkoinen suklaa: Qty 40, Total $520.00
#   • Sasquatch Ale: Qty 30, Total $420.00
#   • Ikura: Qty 18, Total $418.50
#   • Outback Lager: Qty 30, Total $360.00
#   • Chef Anton's Cajun Seasoning: Qty 20, Total $352.00
#   • Original Frankfurter grüne Soße: Qty 35, Total $341.25
#   • Singaporean Hokkien Fried Mee: Qty 22, Total $302.40
#   • Chai: Qty 15, Total $202.50
#   • Rhönbräu Klosterbier: Qty 20, Total $155.00
#   • Camembert Pierrot: Qty 6, Total $146.88
#   • Chartreuse verte: Qty 3, Total $43.20
#
# ============================================================
# Customer: Island Trading
# Customer ID: ISLAT
# Contact: Helen Bennett
# Location: Cowes, UK
# Total Products Purchased: 19
# Grand Total Spent: $6146.30
# ----------------------------------------
# Products:
#   • Sirop d'érable: Qty 30, Total $855.00
#   • Northwoods Cranberry Sauce: Qty 20, Total $800.00
#   • Camembert Pierrot: Qty 21, Total $714.00
#   • Outback Lager: Qty 50, Total $660.00
#   • Gnocchi di nonna Alice: Qty 15, Total $570.00
#   • Flotemysost: Qty 27, Total $528.90
#   • Mozzarella di Giovanni: Qty 10, Total $348.00
#   • Raclette Courdavault: Qty 6, Total $330.00
#   • Lakkalikööri: Qty 16, Total $266.40
#   • Chang: Qty 10, Total $190.00
#   • Sasquatch Ale: Qty 14, Total $156.80
#   • Jack's New England Clam Chowder: Qty 20, Total $154.00
#   • Steeleye Stout: Qty 10, Total $144.00
#   • Tunnbröd: Qty 15, Total $135.00
#   • Tarte au sucre: Qty 2, Total $98.60
#   • Perth Pasties: Qty 2, Total $65.60
#   • Konbu: Qty 10, Total $60.00
#   • Teatime Chocolate Biscuits: Qty 5, Total $46.00
#   • Geitost: Qty 12, Total $24.00
#
# ============================================================
# Customer: Königlich Essen
# Customer ID: KOENE
# Contact: Philip Cramer
# Location: Brandenburg, Germany
# Total Products Purchased: 29
# Grand Total Spent: $30908.38
# ----------------------------------------
# Products:
#   • Côte de Blaye: Qty 30, Total $7905.00
#   • Raclette Courdavault: Qty 85, Total $4279.00
#   • Thüringer Rostbratwurst: Qty 24, Total $2970.96
#   • Tarte au sucre: Qty 45, Total $2033.62
#   • Gumbär Gummibärchen: Qty 58, Total $1539.64
#   • Queso Manchego La Pastora: Qty 36, Total $1368.00
#   • Northwoods Cranberry Sauce: Qty 30, Total $1200.00
#   • Inlagd Sill: Qty 60, Total $1140.00
#   • Pâté chinois: Qty 47, Total $1113.60
#   • Mozzarella di Giovanni: Qty 40, Total $1112.00
#   • Nord-Ost Matjeshering: Qty 43, Total $1071.75
#   • Boston Crab Meat: Qty 60, Total $938.40
#   • Lakkalikööri: Qty 35, Total $630.00
#   • Ipoh Coffee: Qty 15, Total $552.00
#   • Aniseed Syrup: Qty 49, Total $490.00
#   • Pavlova: Qty 20, Total $349.00
#   • Queso Cabrales: Qty 15, Total $299.25
#   • Maxilaku: Qty 21, Total $285.60
#   • Sir Rodney's Scones: Qty 40, Total $272.00
#   • NuNuCa Nuß-Nougat-Creme: Qty 22, Total $271.60
#   • Outback Lager: Qty 14, Total $189.00
#   • Tourtière: Qty 24, Total $169.86
#   • Tofu: Qty 9, Total $167.40
#   • Konbu: Qty 32, Total $159.60
#   • Guaraná Fantástica: Qty 30, Total $121.50
#   • Grandma's Boysenberry Spread: Qty 6, Total $120.00
#   • Genen Shouyu: Qty 5, Total $62.00
#   • Chartreuse verte: Qty 4, Total $57.60
#   • Gorgonzola Telino: Qty 4, Total $40.00
#
# ============================================================
# Customer: LILA-Supermercado
# Customer ID: LILAS
# Contact: Carlos González
# Location: Barquisimeto, Venezuela
# Total Products Purchased: 28
# Grand Total Spent: $16076.60
# ----------------------------------------
# Products:
#   • Raclette Courdavault: Qty 40, Total $1980.00
#   • Mascarpone Fabioli: Qty 50, Total $1600.00
#   • Gumbär Gummibärchen: Qty 66, Total $1456.65
#   • Camembert Pierrot: Qty 43, Total $1126.08
#   • Queso Manchego La Pastora: Qty 30, Total $969.00
#   • Rössle Sauerkraut: Qty 20, Total $912.00
#   • Pâté chinois: Qty 60, Total $864.00
#   • Mozzarella di Giovanni: Qty 28, Total $674.15
#   • Ikura: Qty 30, Total $595.20
#   • Queso Cabrales: Qty 32, Total $579.60
#   • Tunnbröd: Qty 70, Total $535.50
#   • Outback Lager: Qty 35, Total $525.00
#   • Nord-Ost Matjeshering: Qty 32, Total $512.37
#   • Maxilaku: Qty 25, Total $500.00
#   • Gudbrandsdalsost: Qty 15, Total $432.00
#   • Uncle Bob's Organic Dried Pears: Qty 15, Total $427.50
#   • Pavlova: Qty 30, Total $417.00
#   • Original Frankfurter grüne Soße: Qty 30, Total $370.50
#   • Ravioli Angelo: Qty 15, Total $292.50
#   • Genen Shouyu: Qty 20, Total $248.00
#   • Sir Rodney's Scones: Qty 40, Total $240.00
#   • Spegesild: Qty 20, Total $180.00
#   • Teatime Chocolate Biscuits: Qty 18, Total $131.40
#   • Chartreuse verte: Qty 8, Total $122.40
#   • Longlife Tofu: Qty 14, Total $112.00
#   • Tourtière: Qty 20, Total $111.75
#   • Filo Mix: Qty 20, Total $105.00
#   • Konbu: Qty 10, Total $57.00
#
# ============================================================
# Customer: LINO-Delicateses
# Customer ID: LINOD
# Contact: Felipe Izquierdo
# Location: I. de Margarita, Venezuela
# Total Products Purchased: 26
# Grand Total Spent: $16476.56
# ----------------------------------------
# Products:
#   • Mozzarella di Giovanni: Qty 60, Total $2088.00
#   • Maxilaku: Qty 60, Total $1200.00
#   • Carnarvon Tigers: Qty 25, Total $1171.88
#   • Outback Lager: Qty 90, Total $985.50
#   • Chai: Qty 54, Total $954.00
#   • Boston Crab Meat: Qty 50, Total $920.00
#   • Rössle Sauerkraut: Qty 20, Total $912.00
#   • Pavlova: Qty 52, Total $834.11
#   • Inlagd Sill: Qty 50, Total $712.50
#   • Camembert Pierrot: Qty 24, Total $693.60
#   • Valkoinen suklaa: Qty 40, Total $650.00
#   • Steeleye Stout: Qty 33, Total $553.50
#   • Ravioli Angelo: Qty 28, Total $546.00
#   • Aniseed Syrup: Qty 70, Total $544.00
#   • Pâté chinois: Qty 30, Total $518.40
#   • Rogede sild: Qty 50, Total $475.00
#   • Louisiana Fiery Hot Pepper Sauce: Qty 21, Total $442.05
#   • NuNuCa Nuß-Nougat-Creme: Qty 30, Total $403.20
#   • Sir Rodney's Scones: Qty 30, Total $300.00
#   • Escargots de Bourgogne: Qty 30, Total $298.12
#   • Chang: Qty 20, Total $273.60
#   • Gorgonzola Telino: Qty 25, Total $265.62
#   • Jack's New England Clam Chowder: Qty 28, Total $243.18
#   • Teatime Chocolate Biscuits: Qty 22, Total $186.30
#   • Tunnbröd: Qty 18, Total $162.00
#   • Chartreuse verte: Qty 10, Total $144.00
#
# ============================================================
# Customer: La corne d'abondance
# Customer ID: LACOR
# Contact: Daniel Tonini
# Location: Versailles, France
# Total Products Purchased: 11
# Grand Total Spent: $1992.05
# ----------------------------------------
# Products:
#   • Schoggi Schokolade: Qty 10, Total $439.00
#   • Sir Rodney's Marmalade: Qty 5, Total $405.00
#   • Lakkalikööri: Qty 20, Total $360.00
#   • Alice Mutton: Qty 6, Total $234.00
#   • Gumbär Gummibärchen: Qty 5, Total $156.15
#   • Uncle Bob's Organic Dried Pears: Qty 5, Total $150.00
#   • Rhönbräu Klosterbier: Qty 10, Total $77.50
#   • Outback Lager: Qty 4, Total $60.00
#   • Jack's New England Clam Chowder: Qty 6, Total $57.90
#   • Filo Mix: Qty 5, Total $35.00
#   • Geitost: Qty 7, Total $17.50
#
# ============================================================
# Customer: La maison d'Asie
# Customer ID: LAMAI
# Contact: Annette Roulet
# Location: Toulouse, France
# Total Products Purchased: 26
# Grand Total Spent: $9328.20
# ----------------------------------------
# Products:
#   • Thüringer Rostbratwurst: Qty 20, Total $2352.01
#   • Tarte au sucre: Qty 40, Total $1576.00
#   • Gudbrandsdalsost: Qty 28, Total $725.76
#   • Inlagd Sill: Qty 47, Total $661.01
#   • Lakkalikööri: Qty 34, Total $417.60
#   • Ipoh Coffee: Qty 10, Total $368.00
#   • Rössle Sauerkraut: Qty 8, Total $346.56
#   • Chai: Qty 24, Total $345.60
#   • Chang: Qty 15, Total $270.75
#   • Laughing Lumberjack Lager: Qty 24, Total $268.80
#   • Gula Malacca: Qty 16, Total $248.96
#   • Louisiana Fiery Hot Pepper Sauce: Qty 15, Total $226.80
#   • Pavlova: Qty 20, Total $222.40
#   • Genen Shouyu: Qty 12, Total $176.70
#   • Valkoinen suklaa: Qty 15, Total $175.50
#   • Pâté chinois: Qty 10, Total $144.00
#   • Louisiana Hot Spiced Okra: Qty 10, Total $122.40
#   • NuNuCa Nuß-Nougat-Creme: Qty 10, Total $112.00
#   • Singaporean Hokkien Fried Mee: Qty 10, Total $112.00
#   • Sasquatch Ale: Qty 10, Total $106.40
#   • Wimmers gute Semmelknödel: Qty 3, Total $99.75
#   • Spegesild: Qty 10, Total $76.80
#   • Guaraná Fantástica: Qty 20, Total $70.20
#   • Rhönbräu Klosterbier: Qty 8, Total $55.80
#   • Geitost: Qty 20, Total $32.00
#   • Konbu: Qty 3, Total $14.40
#
# ============================================================
# Customer: Laughing Bacchus Wine Cellars
# Customer ID: LAUGB
# Contact: Yoshi Tannamuri
# Location: Vancouver, Canada
# Total Products Purchased: 8
# Grand Total Spent: $522.50
# ----------------------------------------
# Products:
# ...
# Customer: Spécialités du monde
# Customer ID: SPECD
# Contact: Dominique Perrier
# Location: Paris, France
# Total Products Purchased: 6
# Grand Total Spent: $2423.35
# ----------------------------------------
# Products:
#   • Côte de Blaye: Qty 5, Total $1317.50
#   • Carnarvon Tigers: Qty 6, Total $375.00
#   • Gudbrandsdalsost: Qty 10, Total $360.00
#   • Queso Cabrales: Qty 10, Total $210.00
#   • Rhönbräu Klosterbier: Qty 14, Total $108.50
#   • Pavlova: Qty 3, Total $52.35
#
# ============================================================
# Customer: Suprêmes délices
# Customer ID: SUPRD
# Contact: Pascale Cartrain
# Location: Charleroi, Belgium
# Total Products Purchased: 31
# Grand Total Spent: $24088.78
# ----------------------------------------
# Products:
#   • Raclette Courdavault: Qty 50, Total $2750.00
#   • Sir Rodney's Marmalade: Qty 40, Total $2462.40
#   • Rössle Sauerkraut: Qty 58, Total $2111.20
#   • Gnocchi di nonna Alice: Qty 45, Total $1596.00
#   • Flotemysost: Qty 80, Total $1505.00
#   • Alice Mutton: Qty 40, Total $1248.00
#   • Ipoh Coffee: Qty 32, Total $1177.60
#   • Schoggi Schokolade: Qty 25, Total $1097.50
#   • Camembert Pierrot: Qty 40, Total $1088.00
#   • Steeleye Stout: Qty 60, Total $1080.00
#   • Singaporean Hokkien Fried Mee: Qty 82, Total $1008.00
#   • Outback Lager: Qty 60, Total $900.00
#   • Gumbär Gummibärchen: Qty 30, Total $747.00
#   • Louisiana Hot Spiced Okra: Qty 60, Total $693.60
#   • Original Frankfurter grüne Soße: Qty 40, Total $520.00
#   • Lakkalikööri: Qty 42, Total $514.08
#   • Ikura: Qty 16, Total $496.00
#   • Pâté chinois: Qty 25, Total $480.00
#   • Chef Anton's Cajun Seasoning: Qty 21, Total $462.00
#   • Chang: Qty 20, Total $380.00
#   • Sir Rodney's Scones: Qty 36, Total $360.00
#   • Escargots de Bourgogne: Qty 30, Total $318.00
#   • Gorgonzola Telino: Qty 35, Total $297.50
#   • Longlife Tofu: Qty 20, Total $200.00
#   • Chai: Qty 10, Total $180.00
#   • Teatime Chocolate Biscuits: Qty 21, Total $153.30
#   • Tourtière: Qty 10, Total $74.50
#   • Boston Crab Meat: Qty 5, Total $73.60
#   • Guaraná Fantástica: Qty 12, Total $54.00
#   • Geitost: Qty 25, Total $47.50
#   • Filo Mix: Qty 2, Total $14.00
#
# ============================================================
# Customer: The Big Cheese
# Customer ID: THEBI
# Contact: Liz Nixon
# Location: Portland, USA
# Total Products Purchased: 7
# Grand Total Spent: $3361.00
# ----------------------------------------
# Products:
#   • Côte de Blaye: Qty 10, Total $2635.00
#   • Tarte au sucre: Qty 5, Total $197.00
#   • Sasquatch Ale: Qty 10, Total $140.00
#   • Pavlova: Qty 10, Total $139.00
#   • Inlagd Sill: Qty 5, Total $95.00
#   • Chef Anton's Gumbo Mix: Qty 4, Total $85.40
#   • Mozzarella di Giovanni: Qty 2, Total $69.60
#
# ============================================================
# Customer: The Cracker Box
# Customer ID: THECR
# Contact: Liu Wong
# Location: Butte, USA
# Total Products Purchased: 8
# Grand Total Spent: $1947.24
# ----------------------------------------
# Products:
#   • Thüringer Rostbratwurst: Qty 6, Total $742.74
#   • Rössle Sauerkraut: Qty 10, Total $456.00
#   • Gula Malacca: Qty 10, Total $194.50
#   • Ikura: Qty 6, Total $186.00
#   • Boston Crab Meat: Qty 10, Total $184.00
#   • Chai: Qty 4, Total $72.00
#   • Filo Mix: Qty 10, Total $70.00
#   • Laughing Lumberjack Lager: Qty 3, Total $42.00
#
# ============================================================
# Customer: Toms Spezialitäten
# Customer ID: TOMSP
# Contact: Karin Josephs
# Location: Münster, Germany
# Total Products Purchased: 11
# Grand Total Spent: $4778.14
# ----------------------------------------
# Products:
#   • Manjimup Dried Apples: Qty 40, Total $1696.00
#   • Gnocchi di nonna Alice: Qty 28, Total $1064.00
#   • Maxilaku: Qty 40, Total $800.00
#   • Sasquatch Ale: Qty 30, Total $284.20
#   • Teatime Chocolate Biscuits: Qty 39, Total $276.84
#   • Ravioli Angelo: Qty 15, Total $187.20
#   • Tofu: Qty 9, Total $167.40
#   • Jack's New England Clam Chowder: Qty 14, Total $135.10
#   • Filo Mix: Qty 15, Total $75.60
#   • Guaraná Fantástica: Qty 20, Total $64.80
#   • Gorgonzola Telino: Qty 3, Total $27.00
#
# ============================================================
# Customer: Tortuga Restaurante
# Customer ID: TORTU
# Contact: Miguel Angel Paolino
# Location: México D.F., Mexico
# Total Products Purchased: 24
# Grand Total Spent: $10812.15
# ----------------------------------------
# Products:
#   • Côte de Blaye: Qty 15, Total $3952.50
#   • Gula Malacca: Qty 51, Total $991.95
#   • Alice Mutton: Qty 18, Total $639.60
#   • Carnarvon Tigers: Qty 12, Total $600.00
#   • Rössle Sauerkraut: Qty 14, Total $509.60
#   • Maxilaku: Qty 30, Total $480.00
#   • Raclette Courdavault: Qty 10, Total $440.00
#   • Ikura: Qty 17, Total $434.00
#   • Lakkalikööri: Qty 30, Total $432.00
#   • Chartreuse verte: Qty 20, Total $360.00
#   • Queso Cabrales: Qty 15, Total $315.00
#   • Gorgonzola Telino: Qty 20, Total $250.00
#   • Scottish Longbreads: Qty 20, Total $250.00
#   • Ipoh Coffee: Qty 5, Total $230.00
#   • Chai: Qty 10, Total $180.00
#   • Outback Lager: Qty 12, Total $180.00
#   • Vegie-spread: Qty 5, Total $175.50
#   • Geitost: Qty 30, Total $75.00
#   • Tourtière: Qty 10, Total $74.50
#   • Teatime Chocolate Biscuits: Qty 7, Total $64.40
#   • Guaraná Fantástica: Qty 15, Total $58.50
#   • Konbu: Qty 10, Total $48.00
#   • Rhönbräu Klosterbier: Qty 6, Total $37.20
#   • Flotemysost: Qty 2, Total $34.40
#
# ============================================================
# Customer: Tradição Hipermercados
# Customer ID: TRADH
# Contact: Anabela Domingues
# Location: Sao Paulo, Brazil
# Total Products Purchased: 13
# Grand Total Spent: $6850.66
# ----------------------------------------
# Products:
#   • Sir Rodney's Marmalade: Qty 20, Total $1296.00
#   • Camembert Pierrot: Qty 30, Total $1020.00
#   • Thüringer Rostbratwurst: Qty 8, Total $940.80
#   • Chartreuse verte: Qty 28, Total $504.00
#   • Nord-Ost Matjeshering: Qty 20, Total $491.91
#   • Mozzarella di Giovanni: Qty 15, Total $469.80
#   • Tarte au sucre: Qty 10, Total $394.40
#   • Pâté chinois: Qty 20, Total $384.00
#   • Escargots de Bourgogne: Qty 30, Total $357.75
#   • Chef Anton's Cajun Seasoning: Qty 20, Total $352.00
#   • Scottish Longbreads: Qty 24, Total $300.00
#   • Gorgonzola Telino: Qty 20, Total $190.00
#   • Grandma's Boysenberry Spread: Qty 6, Total $150.00
#
# ============================================================
# Customer: Trail's Head Gourmet Provisioners
# Customer ID: TRAIH
# Contact: Helvetius Nagy
# Location: Kirkland, USA
# Total Products Purchased: 8
# Grand Total Spent: $1571.20
# ----------------------------------------
# Products:
#   • Tarte au sucre: Qty 13, Total $640.90
#   • Original Frankfurter grüne Soße: Qty 18, Total $234.00
#   • Wimmers gute Semmelknödel: Qty 6, Total $199.50
#   • Chartreuse verte: Qty 10, Total $180.00
#   • Rhönbräu Klosterbier: Qty 20, Total $155.00
#   • Outback Lager: Qty 6, Total $90.00
#   • Boston Crab Meat: Qty 2, Total $36.80
#   • Geitost: Qty 14, Total $35.00
#
# ============================================================
# Customer: Vaffeljernet
# Customer ID: VAFFE
# Contact: Palle Ibsen
# Location: Århus, Denmark
# Total Products Purchased: 23
# Grand Total Spent: $15843.92
# ----------------------------------------
# Products:
#   • Rössle Sauerkraut: Qty 60, Total $2462.40
#   • Vegie-spread: Qty 40, Total $1756.00
#   • Thüringer Rostbratwurst: Qty 18, Total $1603.80
#   • Ikura: Qty 43, Total $1277.20
#   • Boston Crab Meat: Qty 70, Total $1030.00
#   • Raclette Courdavault: Qty 18, Total $940.50
#   • Original Frankfurter grüne Soße: Qty 66, Total $787.15
#   • Tarte au sucre: Qty 15, Total $739.50
#   • Scottish Longbreads: Qty 60, Total $600.00
#   • Sasquatch Ale: Qty 50, Total $599.20
#   • Sirop d'érable: Qty 20, Total $570.00
#   • Flotemysost: Qty 30, Total $516.00
#   • Lakkalikööri: Qty 35, Total $504.00
#   • Tourtière: Qty 68, Total $478.70
#   • Valkoinen suklaa: Qty 25, Total $325.00
#   • Uncle Bob's Organic Dried Pears: Qty 10, Total $300.00
#   • Jack's New England Clam Chowder: Qty 30, Total $275.02
#   • Louisiana Fiery Hot Pepper Sauce: Qty 15, Total $252.00
#   • Rogede sild: Qty 30, Total $205.20
#   • Guaraná Fantástica: Qty 50, Total $202.50
#   • Steeleye Stout: Qty 10, Total $180.00
#   • Aniseed Syrup: Qty 14, Total $140.00
#   • Filo Mix: Qty 15, Total $99.75
#
# ============================================================
# Customer: Victuailles en stock
# Customer ID: VICTE
# Contact: Mary Saveley
# Location: Lyon, France
# Total Products Purchased: 22
# Grand Total Spent: $9182.43
# ----------------------------------------
# Products:
#   • Tarte au sucre: Qty 40, Total $1972.00
#   • Mozzarella di Giovanni: Qty 40, Total $1112.00
#   • Ikura: Qty 40, Total $868.00
#   • Ipoh Coffee: Qty 20, Total $782.00
#   • Sirop d'érable: Qty 30, Total $726.75
#   • Uncle Bob's Organic Dried Pears: Qty 26, Total $664.80
#   • Steeleye Stout: Qty 30, Total $540.00
#   • Outback Lager: Qty 30, Total $382.50
#   • Louisiana Fiery Hot Pepper Sauce: Qty 22, Total $378.10
#   • Chang: Qty 20, Total $285.00
#   • NuNuCa Nuß-Nougat-Creme: Qty 20, Total $238.00
#   • Ravioli Angelo: Qty 15, Total $222.30
#   • Jack's New England Clam Chowder: Qty 20, Total $193.00
#   • Spegesild: Qty 20, Total $182.40
#   • Manjimup Dried Apples: Qty 4, Total $159.00
#   • Longlife Tofu: Qty 15, Total $112.50
#   • Scottish Longbreads: Qty 10, Total $100.00
#   • Gustaf's Knäckebröd: Qty 6, Total $95.76
#   • Chocolade: Qty 8, Total $86.70
#   • Filo Mix: Qty 8, Total $44.80
#   • Tourtière: Qty 6, Total $28.32
#   • Geitost: Qty 4, Total $8.50
#
# ============================================================
# Customer: Vins et alcools Chevalier
# Customer ID: VINET
# Contact: Paul Henriot
# Location: Reims, France
# Total Products Purchased: 9
# Grand Total Spent: $1480.00
# ----------------------------------------
# Products:
#   • Mozzarella di Giovanni: Qty 12, Total $368.60
#   • Flotemysost: Qty 20, Total $344.00
#   • Queso Cabrales: Qty 12, Total $168.00
#   • Filo Mix: Qty 18, Total $126.00
#   • Gnocchi di nonna Alice: Qty 4, Total $121.60
#   • Jack's New England Clam Chowder: Qty 12, Total $115.80
#   • Inlagd Sill: Qty 6, Total $114.00
#   • Singaporean Hokkien Fried Mee: Qty 10, Total $98.00
#   • Konbu: Qty 4, Total $24.00
#
# ============================================================
# Customer: Wartian Herkku
# Customer ID: WARTH
# Contact: Pirkko Koskitalo
# Location: Oulu, Finland
# Total Products Purchased: 28
# Grand Total Spent: $15648.70
# ----------------------------------------
# Products:
#   • Perth Pasties: Qty 75, Total $1965.00
#   • Flotemysost: Qty 100, Total $1651.20
#   • Gnocchi di nonna Alice: Qty 50, Total $1577.00
#   • Thüringer Rostbratwurst: Qty 10, Total $1237.90
#   • Raclette Courdavault: Qty 25, Total $1168.75
#   • Ipoh Coffee: Qty 25, Total $920.00
#   • Camembert Pierrot: Qty 24, Total $693.60
#   • Tofu: Qty 35, Total $619.61
#   • Sirop d'érable: Qty 25, Total $570.00
#   • Chef Anton's Cajun Seasoning: Qty 25, Total $550.00
#   • Gustaf's Knäckebröd: Qty 24, Total $504.00
#   • Inlagd Sill: Qty 30, Total $456.00
#   • Gorgonzola Telino: Qty 30, Total $375.00
#   • Longlife Tofu: Qty 35, Total $350.00
#   • Queso Manchego La Pastora: Qty 12, Total $346.56
#   • Rogede sild: Qty 40, Total $323.00
#   • Queso Cabrales: Qty 15, Total $315.00
#   • Ravioli Angelo: Qty 20, Total $312.00
#   • Gudbrandsdalsost: Qty 10, Total $306.00
#   • Chartreuse verte: Qty 20, Total $288.00
#   • Chai: Qty 18, Total $284.40
#   • Pavlova: Qty 14, Total $244.30
#   • Konbu: Qty 30, Total $168.00
#   • Teatime Chocolate Biscuits: Qty 20, Total $146.00
#   • Steeleye Stout: Qty 6, Total $108.00
#   • Escargots de Bourgogne: Qty 6, Total $79.50
#   • Sir Rodney's Scones: Qty 10, Total $72.00
#   • Tourtière: Qty 3, Total $17.88
#
# ============================================================
# Customer: Wellington Importadora
# Customer ID: WELLI
# Contact: Paula Parente
# Location: Resende, Brazil
# Total Products Purchased: 16
# Grand Total Spent: $6068.20
# ----------------------------------------
# Products:
#   • Mishi Kobe Niku: Qty 20, Total $1396.80
#   • Ipoh Coffee: Qty 20, Total $920.00
#   • Raclette Courdavault: Qty 15, Total $783.75
#   • Chai: Qty 41, Total $720.00
#   • Carnarvon Tigers: Qty 8, Total $412.50
#   • Perth Pasties: Qty 15, Total $393.00
#   • Spegesild: Qty 21, Total $226.80
#   • Röd Kaviar: Qty 20, Total $216.00
#   • Teatime Chocolate Biscuits: Qty 24, Total $209.76
#   • NuNuCa Nuß-Nougat-Creme: Qty 15, Total $199.50
#   • Zaanse koeken: Qty 15, Total $142.50
#   • Filo Mix: Qty 20, Total $140.00
#   • Original Frankfurter grüne Soße: Qty 12, Total $124.80
#   • Outback Lager: Qty 11, Total $120.15
#   • Tunnbröd: Qty 8, Total $54.00
#   • Konbu: Qty 2, Total $8.64
#
# ============================================================
# Customer: White Clover Markets
# Customer ID: WHITC
# Contact: Karl Jablonski
# Location: Seattle, USA
# Total Products Purchased: 32
# Grand Total Spent: $27363.60
# ----------------------------------------
# Products:
#   • Côte de Blaye: Qty 25, Total $6587.50
#   • Alice Mutton: Qty 62, Total $2418.00
#   • Tarte au sucre: Qty 38, Total $1873.40
#   • Northwoods Cranberry Sauce: Qty 70, Total $1680.00
#   • Raclette Courdavault: Qty 30, Total $1650.00
#   • Carnarvon Tigers: Qty 20, Total $1250.00
#   • Gudbrandsdalsost: Qty 30, Total $918.00
#   • Sasquatch Ale: Qty 70, Total $862.40
#   • Vegie-spread: Qty 24, Total $842.88
#   • Chang: Qty 52, Total $744.80
#   • Sirop d'érable: Qty 25, Total $712.50
#   • Inlagd Sill: Qty 35, Total $665.00
#   • Chef Anton's Cajun Seasoning: Qty 35, Total $616.00
#   • Mishi Kobe Niku: Qty 6, Total $582.00
#   • Gnocchi di nonna Alice: Qty 19, Total $577.60
#   • Mozzarella di Giovanni: Qty 20, Total $528.20
#   • Sir Rodney's Scones: Qty 52, Total $520.00
#   • Steeleye Stout: Qty 35, Total $504.00
#   • Gumbär Gummibärchen: Qty 15, Total $468.45
#   • Pavlova: Qty 38, Total $465.88
#   • Teatime Chocolate Biscuits: Qty 42, Total $386.40
#   • Tourtière: Qty 60, Total $379.95
#   • Perth Pasties: Qty 10, Total $328.00
#   • Rogede sild: Qty 40, Total $304.00
#   • Original Frankfurter grüne Soße: Qty 30, Total $296.40
#   • Spegesild: Qty 18, Total $216.00
#   • Geitost: Qty 95, Total $201.50
#   • Escargots de Bourgogne: Qty 15, Total $198.75
#   • Röd Kaviar: Qty 15, Total $191.25
#   • Rhönbräu Klosterbier: Qty 30, Total $186.00
#   • Rössle Sauerkraut: Qty 5, Total $182.40
#   • Gula Malacca: Qty 2, Total $26.35
#
# ============================================================
# Customer: Wilman Kala
# Customer ID: WILMK
# Contact: Matti Karttunen
# Location: Helsinki, Finland
# Total Products Purchased: 17
# Grand Total Spent: $3161.35
# ----------------------------------------
# Products:
#   • Raclette Courdavault: Qty 10, Total $550.00
#   • Northwoods Cranberry Sauce: Qty 10, Total $400.00
#   • Ipoh Coffee: Qty 6, Total $276.00
#   • Boston Crab Meat: Qty 12, Total $220.80
#   • Louisiana Fiery Hot Pepper Sauce: Qty 10, Total $210.50
#   • Sir Rodney's Scones: Qty 20, Total $200.00
#   • Maxilaku: Qty 10, Total $200.00
#   • Lakkalikööri: Qty 10, Total $180.00
#   • Queso Manchego La Pastora: Qty 4, Total $152.00
#   • Sirop d'érable: Qty 5, Total $142.50
#   • Rössle Sauerkraut: Qty 3, Total $136.80
#   • Pâté chinois: Qty 5, Total $120.00
#   • Teatime Chocolate Biscuits: Qty 12, Total $110.40
#   • Guaraná Fantástica: Qty 20, Total $90.00
#   • Singaporean Hokkien Fried Mee: Qty 6, Total $84.00
#   • Pavlova: Qty 3, Total $52.35
#   • Chai: Qty 2, Total $36.00
#
# ============================================================
# Customer: Wolski  Zajazd
# Customer ID: WOLZA
# Contact: Zbyszek Piestrzeniewicz
# Location: Warszawa, Poland
# Total Products Purchased: 14
# Grand Total Spent: $3531.95
# ----------------------------------------
# Products:
#   • Sirop d'érable: Qty 22, Total $627.00
#   • Tarte au sucre: Qty 12, Total $591.60
#   • Camembert Pierrot: Qty 15, Total $510.00
#   • Chang: Qty 20, Total $380.00
#   • Gorgonzola Telino: Qty 30, Total $300.00
#   • Rhönbräu Klosterbier: Qty 30, Total $232.50
#   • Longlife Tofu: Qty 20, Total $200.00
#   • Scottish Longbreads: Qty 15, Total $187.50
#   • Escargots de Bourgogne: Qty 15, Total $159.00
#   • Chai: Qty 6, Total $108.00
#   • Manjimup Dried Apples: Qty 2, Total $106.00
#   • Guaraná Fantástica: Qty 12, Total $54.00
#   • Steeleye Stout: Qty 3, Total $54.00
#   • Tourtière: Qty 3, Total $22.35

# %% [markdown]
# ## 1D) Create Materialised View: customer_sales_summary
#
# Create a materialised "view" collection with:
# - Total number of orders
# - Total quantity purchased (sum of all products)
# - Total revenue
# - List of unique product categories purchased
# - First and most recent order dates
#
# This query uses `$out` stage to store the aggregation result as a new collection.

# %%
# Query 1D: Create materialised view customer_sales_summary
# Use $out to store result as new collection

pipeline_1d = [
    # Lookup customer information
    {
        "$lookup": {
            "from": "customers",
            "localField": "customer_id",
            "foreignField": "_id",
            "as": "customer"
        }
    },
    {
        "$unwind": "$customer"
    },
    # Unwind order details
    {
        "$unwind": "$orderDetails"
    },
    # Group by customer to calculate metrics
    {
        "$group": {
            "_id": "$customer._id",
            "customerId": {"$first": "$customer.customerId"},
            "companyName": {"$first": "$customer.companyName"},
            "contactName": {"$first": "$customer.contactName"},
            "city": {"$first": "$customer.city"},
            "country": {"$first": "$customer.country"},
            # Collect unique order IDs to count orders
            "orderIds": {"$addToSet": "$orderId"},
            # Total quantity purchased (sum of all products)
            "totalQuantityPurchased": {"$sum": "$orderDetails.quantity"},
            # Total revenue
            "totalRevenue": {
                "$sum": {
                    "$multiply": [
                        "$orderDetails.unitPrice",
                        "$orderDetails.quantity",
                        {"$subtract": [1, "$orderDetails.discount"]}
                    ]
                }
            },
            # Collect unique categories
            "categories": {"$addToSet": "$orderDetails.category.categoryName"},
            # First order date (minimum)
            "firstOrderDate": {"$min": "$orderDate"},
            # Most recent order date (maximum)
            "mostRecentOrderDate": {"$max": "$orderDate"}
        }
    },
    # Project final format
    {
        "$project": {
            "_id": 1,
            "customerId": 1,
            "companyName": 1,
            "contactName": 1,
            "city": 1,
            "country": 1,
            "totalOrders": {"$size": "$orderIds"},
            "totalQuantityPurchased": 1,
            "totalRevenue": {"$round": ["$totalRevenue", 2]},
            "uniqueProductCategories": {
                "$filter": {
                    "input": "$categories",
                    "as": "cat",
                    "cond": {"$ne": ["$$cat", None]}
                }
            },
            "firstOrderDate": 1,
            "mostRecentOrderDate": 1
        }
    },
    # Sort by total revenue descending
    {
        "$sort": {"totalRevenue": -1}
    },
    # Output to materialised view collection
    {
        "$out": "customer_sales_summary"
    }
]

# Execute aggregation pipeline (creates materialised view)
# Use list() to ensure pipeline executes fully
list(db["orders"].aggregate(pipeline_1d))

print("Materialised view 'customer_sales_summary' created successfully!")
# Out:
# Materialised view 'customer_sales_summary' created successfully!

# %%
# Verify materialised view and show results
view_count = db["customer_sales_summary"].count_documents({})
print(f"Total documents in customer_sales_summary: {view_count}")

print("\n=== Customer Sales Summary (Materialised View) ===")
print("\nTop 10 customers by revenue:")

# Query materialised view
results = list(db["customer_sales_summary"].find().sort("totalRevenue", -1).limit(10))

for doc in results:
    print(f"\n{'='*60}")
    print(f"Customer: {doc['companyName']} ({doc['customerId']})")
    print(f"Contact: {doc['contactName']}")
    print(f"Location: {doc['city']}, {doc['country']}")
    print(f"Total Orders: {doc['totalOrders']}")
    print(f"Total Quantity Purchased: {doc['totalQuantityPurchased']}")
    print(f"Total Revenue: ${doc['totalRevenue']:.2f}")
    print(f"Product Categories: {', '.join(doc['uniqueProductCategories'])}")
    print(f"First Order Date: {doc['firstOrderDate']}")
    print(f"Most Recent Order Date: {doc['mostRecentOrderDate']}")
# Out:
# Total documents in customer_sales_summary: 89
#
# === Customer Sales Summary (Materialised View) ===
#
# Top 10 customers by revenue:
#
# ============================================================
# Customer: QUICK-Stop (QUICK)
# Contact: Horst Kloss
# Location: Cunewalde, Germany
# Total Orders: 28
# Total Quantity Purchased: 3961
# Total Revenue: $110277.30
# Product Categories: Seafood, Confections, Grains/Cereals, Dairy Products, Beverages, Produce, Meat/Poultry, Condiments
# First Order Date: 1996-08-05
# Most Recent Order Date: 1998-04-14
#
# ============================================================
# Customer: Ernst Handel (ERNSH)
# Contact: Roland Mendel
# Location: Graz, Austria
# Total Orders: 30
# Total Quantity Purchased: 4543
# Total Revenue: $104874.98
# Product Categories: Confections, Produce, Beverages, Dairy Products, Condiments, Meat/Poultry, Seafood, Grains/Cereals
# First Order Date: 1996-07-17
# Most Recent Order Date: 1998-05-05
#
# ============================================================
# Customer: Save-a-lot Markets (SAVEA)
# Contact: Jose Pavarotti
# Location: Boise, USA
# Total Orders: 31
# Total Quantity Purchased: 4958
# Total Revenue: $104361.95
# Product Categories: Condiments, Meat/Poultry, Produce, Beverages, Dairy Products, Grains/Cereals, Confections, Seafood
# First Order Date: 1996-10-08
# Most Recent Order Date: 1998-05-01
#
# ============================================================
# Customer: Rattlesnake Canyon Grocery (RATTC)
# Contact: Paula Wilson
# Location: Albuquerque, USA
# Total Orders: 18
# Total Quantity Purchased: 1383
# Total Revenue: $51097.80
# Product Categories: Condiments, Meat/Poultry, Dairy Products, Produce, Beverages, Grains/Cereals, Confections, Seafood
# First Order Date: 1996-07-22
# Most Recent Order Date: 1998-05-06
#
# ============================================================
# Customer: Hungry Owl All-Night Grocers (HUNGO)
# Contact: Patricia McKenna
# Location: Cork, Ireland
# Total Orders: 19
# Total Quantity Purchased: 1684
# Total Revenue: $49979.90
# Product Categories: Condiments, Meat/Poultry, Dairy Products, Beverages, Produce, Grains/Cereals, Confections, Seafood
# First Order Date: 1996-09-05
# Most Recent Order Date: 1998-04-30
#
# ============================================================
# Customer: Hanari Carnes (HANAR)
# Contact: Mario Pontes
# Location: Rio de Janeiro, Brazil
# Total Orders: 14
# Total Quantity Purchased: 839
# Total Revenue: $32841.37
# Product Categories: Condiments, Meat/Poultry, Dairy Products, Beverages, Produce, Grains/Cereals, Confections, Seafood
# First Order Date: 1996-07-08
# Most Recent Order Date: 1998-04-27
#
# ============================================================
# Customer: Königlich Essen (KOENE)
# Contact: Philip Cramer
# Location: Brandenburg, Germany
# Total Orders: 14
# Total Quantity Purchased: 903
# Total Revenue: $30908.38
# Product Categories: Seafood, Meat/Poultry, Confections, Beverages, Produce, Dairy Products, Condiments
# First Order Date: 1996-10-07
# Most Recent Order Date: 1998-04-16
#
# ============================================================
# Customer: Folk och fä HB (FOLKO)
# Contact: Maria Larsson
# Location: Bräcke, Sweden
# Total Orders: 19
# Total Quantity Purchased: 1234
# Total Revenue: $29567.56
# Product Categories: Condiments, Seafood, Meat/Poultry, Grains/Cereals, Confections, Produce, Beverages, Dairy Products
# First Order Date: 1996-07-24
# Most Recent Order Date: 1998-04-27
#
# ============================================================
# Customer: Mère Paillarde (MEREP)
# Contact: Jean Fresnière
# Location: Montréal, Canada
# Total Orders: 13
# Total Quantity Purchased: 966
# Total Revenue: $28872.19
# Product Categories: Seafood, Confections, Grains/Cereals, Dairy Products, Beverages, Produce, Condiments, Meat/Poultry
# First Order Date: 1996-10-17
# Most Recent Order Date: 1997-10-30
#
# ============================================================
# Customer: White Clover Markets (WHITC)
# Contact: Karl Jablonski
# Location: Seattle, USA
# Total Orders: 14
# Total Quantity Purchased: 1063
# Total Revenue: $27363.60
# Product Categories: Dairy Products, Beverages, Produce, Condiments, Meat/Poultry, Seafood, Grains/Cereals, Confections
# First Order Date: 1996-07-31
# Most Recent Order Date: 1998-05-01

# %%
# Show all documents in materialised view (sorted by company name)
print("=== Complete Customer Sales Summary (Materialised View) ===")

all_results = list(db["customer_sales_summary"].find().sort("companyName", 1))

for doc in all_results:
    print(f"\n{'-'*60}")
    print(f"Customer ID: {doc['customerId']}")
    print(f"Company: {doc['companyName']}")
    print(f"Contact: {doc['contactName']}")
    print(f"Location: {doc['city']}, {doc['country']}")
    print(f"Total Orders: {doc['totalOrders']}")
    print(f"Total Quantity: {doc['totalQuantityPurchased']}")
    print(f"Total Revenue: ${doc['totalRevenue']:.2f}")
    print(f"Categories: {', '.join(doc['uniqueProductCategories'])}")
    print(f"Order Period: {doc['firstOrderDate']} to {doc['mostRecentOrderDate']}")
# Out:
# === Complete Customer Sales Summary (Materialised View) ===
#
# ------------------------------------------------------------
# Customer ID: ALFKI
# Company: Alfreds Futterkiste
# Contact: Maria Anders
# Location: Berlin, Germany
# Total Orders: 6
# Total Quantity: 174
# Total Revenue: $4273.00
# Categories: Seafood, Beverages, Produce, Dairy Products, Condiments
# Order Period: 1997-08-25 to 1998-04-09
#
# ------------------------------------------------------------
# Customer ID: ANATR
# Company: Ana Trujillo Emparedados y helados
# Contact: Ana Trujillo
# Location: México D.F., Mexico
# Total Orders: 4
# Total Quantity: 63
# Total Revenue: $1402.95
# Categories: Seafood, Confections, Grains/Cereals, Dairy Products, Beverages, Produce
# Order Period: 1996-09-18 to 1998-03-04
#
# ------------------------------------------------------------
# Customer ID: ANTON
# Company: Antonio Moreno Taquería
# Contact: Antonio Moreno
# Location: México D.F., Mexico
# Total Orders: 7
# Total Quantity: 359
# Total Revenue: $7023.98
# Categories: Meat/Poultry, Condiments, Beverages, Dairy Products, Grains/Cereals, Confections, Seafood
# Order Period: 1996-11-27 to 1998-01-28
#
# ------------------------------------------------------------
# Customer ID: AROUT
# Company: Around the Horn
# Contact: Thomas Hardy
# Location: London, UK
# Total Orders: 13
# Total Quantity: 650
# Total Revenue: $13390.65
# Categories: Meat/Poultry, Beverages, Produce, Dairy Products, Confections, Grains/Cereals, Seafood
# Order Period: 1996-11-15 to 1998-04-10
#
# ------------------------------------------------------------
# Customer ID: BSBEV
# Company: B's Beverages
# Contact: Victoria Ashworth
# Location: London, UK
# Total Orders: 10
# Total Quantity: 293
# Total Revenue: $6089.90
# Categories: Confections, Produce, Beverages, Dairy Products, Condiments, Seafood, Grains/Cereals
# Order Period: 1996-08-26 to 1998-04-14
#
# ------------------------------------------------------------
# Customer ID: BERGS
# Company: Berglunds snabbköp
# Contact: Christina Berglund
# Location: Luleå, Sweden
# Total Orders: 18
# Total Quantity: 1001
# Total Revenue: $24927.58
# Categories: Condiments, Meat/Poultry, Dairy Products, Beverages, Produce, Grains/Cereals, Confections, Seafood
# Order Period: 1996-08-12 to 1998-03-04
#
# ------------------------------------------------------------
# Customer ID: BLAUS
# Company: Blauer See Delikatessen
# Contact: Hanna Moos
# Location: Mannheim, Germany
# Total Orders: 7
# Total Quantity: 140
# Total Revenue: $3239.80
# Categories: Seafood, Confections, Grains/Cereals, Produce, Beverages, Dairy Products, Meat/Poultry, Condiments
# Order Period: 1997-04-09 to 1998-04-29
#
# ------------------------------------------------------------
# Customer ID: BLONP
# Company: Blondesddsl père et fils
# Contact: Frédérique Citeaux
# Location: Strasbourg, France
# Total Orders: 11
# Total Quantity: 666
# Total Revenue: $18534.08
# Categories: Seafood, Confections, Grains/Cereals, Beverages, Dairy Products, Produce, Meat/Poultry
# Order Period: 1996-07-25 to 1998-01-12
#
# ------------------------------------------------------------
# Customer ID: BONAP
# Company: Bon app'
# Contact: Laurence Lebihan
# Location: Marseille, France
# Total Orders: 17
# Total Quantity: 980
# Total Revenue: $21963.25
# Categories: Beverages, Produce, Dairy Products, Meat/Poultry, Condiments, Seafood, Grains/Cereals, Confections
# Order Period: 1996-10-16 to 1998-05-06
#
# ------------------------------------------------------------
# Customer ID: BOTTM
# Company: Bottom-Dollar Markets
# Contact: Elizabeth Lincoln
# Location: Tsawassen, Canada
# Total Orders: 14
# Total Quantity: 956
# Total Revenue: $20801.60
# Categories: Seafood, Confections, Grains/Cereals, Produce, Beverages, Dairy Products, Meat/Poultry, Condiments
# Order Period: 1996-12-20 to 1998-04-24
#
# ------------------------------------------------------------
# Customer ID: BOLID
# Company: Bólido Comidas preparadas
# Contact: Martín Sommer
# Location: Madrid, Spain
# Total Orders: 3
# Total Quantity: 190
# Total Revenue: $4232.85
# Categories: Meat/Poultry, Beverages, Grains/Cereals, Condiments
# Order Period: 1996-10-10 to 1998-03-24
#
# ------------------------------------------------------------
# Customer ID: CACTU
# Company: Cactus Comidas para llevar
# Contact: Patricio Simpson
# Location: Buenos Aires, Argentina
# Total Orders: 6
# Total Quantity: 115
# Total Revenue: $1814.80
# Categories: Seafood, Beverages, Dairy Products, Produce, Confections
# Order Period: 1997-04-29 to 1998-04-28
#
# ------------------------------------------------------------
# Customer ID: CENTC
# Company: Centro comercial Moctezuma
# Contact: Francisco Chang
# Location: México D.F., Mexico
# Total Orders: 1
# Total Quantity: 11
# Total Revenue: $100.80
# Categories: Confections, Seafood
# Order Period: 1996-07-18 to 1996-07-18
#
# ------------------------------------------------------------
# Customer ID: CHOPS
# Company: Chop-suey Chinese
# Contact: Yang Wang
# Location: Bern, Switzerland
# Total Orders: 8
# Total Quantity: 465
# Total Revenue: $12348.88
# Categories: Confections, Grains/Cereals, Seafood, Meat/Poultry, Condiments, Produce, Beverages, Dairy Products
# Order Period: 1996-07-11 to 1998-04-22
#
# ------------------------------------------------------------
# Customer ID: COMMI
# Company: Comércio Mineiro
# Contact: Pedro Afonso
# Location: Sao Paulo, Brazil
# Total Orders: 5
# Total Quantity: 133
# Total Revenue: $3810.75
# Categories: Condiments, Meat/Poultry, Confections, Grains/Cereals, Dairy Products, Seafood
# Order Period: 1996-08-27 to 1998-04-22
#
# ------------------------------------------------------------
# Customer ID: CONSH
# Company: Consolidated Holdings
# Contact: Elizabeth Brown
# Location: London, UK
# Total Orders: 3
# Total Quantity: 87
# Total Revenue: $1719.10
# Categories: Seafood, Condiments, Grains/Cereals, Meat/Poultry, Beverages, Dairy Products
# Order Period: 1997-02-04 to 1998-01-23
#
# ------------------------------------------------------------
# Customer ID: WANDK
# Company: Die Wandernde Kuh
# Contact: Rita Müller
# Location: Stuttgart, Germany
# Total Orders: 10
# Total Quantity: 492
# Total Revenue: $9588.42
# Categories: Beverages, Produce, Dairy Products, Meat/Poultry, Condiments, Seafood, Grains/Cereals, Confections
# Order Period: 1996-09-09 to 1998-04-23
#
# ------------------------------------------------------------
# Customer ID: DRACD
# Company: Drachenblut Delikatessen
# Contact: Sven Ottlieb
# Location: Aachen, Germany
# Total Orders: 6
# Total Quantity: 160
# Total Revenue: $3763.21
# Categories: Seafood, Meat/Poultry, Dairy Products, Beverages, Confections
# Order Period: 1996-11-26 to 1998-05-04
#
# ------------------------------------------------------------
# Customer ID: DUMON
# Company: Du monde entier
# Contact: Janine Labrune
# Location: Nantes, France
# Total Orders: 4
# Total Quantity: 80
# Total Revenue: $1615.90
# Categories: Seafood, Meat/Poultry, Dairy Products, Beverages, Grains/Cereals, Confections
# Order Period: 1996-09-20 to 1998-02-16
#
# ------------------------------------------------------------
# Customer ID: EASTC
# Company: Eastern Connection
# Contact: Ann Devon
# Location: London, UK
# Total Orders: 8
# Total Quantity: 569
# Total Revenue: $14761.03
# Categories: Seafood, Meat/Poultry, Condiments, Produce, Beverages, Dairy Products, Confections
# Order Period: 1996-11-26 to 1998-04-28
#
# ------------------------------------------------------------
# Customer ID: ERNSH
# Company: Ernst Handel
# Contact: Roland Mendel
# Location: Graz, Austria
# Total Orders: 30
# Total Quantity: 4543
# Total Revenue: $104874.98
# Categories: Confections, Produce, Beverages, Dairy Products, Condiments, Meat/Poultry, Seafood, Grains/Cereals
# Order Period: 1996-07-17 to 1998-05-05
#
# ------------------------------------------------------------
# Customer ID: FAMIA
# Company: Familia Arquibaldo
# Contact: Aria Cruz
# Location: Sao Paulo, Brazil
# Total Orders: 7
# Total Quantity: 357
# Total Revenue: $4107.55
# Categories: Grains/Cereals, Beverages, Dairy Products, Seafood, Confections, Meat/Poultry
# Order Period: 1996-11-06 to 1997-10-31
#
# ------------------------------------------------------------
# Customer ID: FOLIG
# Company: Folies gourmandes
# Contact: Martine Rancé
# Location: Lille, France
# Total Orders: 5
# Total Quantity: 354
# Total Revenue: $11666.90
# Categories: Dairy Products, Produce, Beverages, Meat/Poultry, Condiments, Seafood, Grains/Cereals, Confections
# Order Period: 1997-01-08 to 1997-12-22
#
# ------------------------------------------------------------
# Customer ID: FOLKO
# Company: Folk och fä HB
# Contact: Maria Larsson
# Location: Bräcke, Sweden
# Total Orders: 19
# Total Quantity: 1234
# Total Revenue: $29567.56
# Categories: Condiments, Seafood, Meat/Poultry, Grains/Cereals, Confections, Produce, Beverages, Dairy Products
# Order Period: 1996-07-24 to 1998-04-27
#
# ------------------------------------------------------------
# Customer ID: FRANR
# Company: France restauration
# Contact: Carine Schmitt
# Location: Nantes, France
# Total Orders: 3
# Total Quantity: 69
# Total Revenue: $3172.16
# Categories: Confections, Condiments, Meat/Poultry, Produce, Beverages
# Order Period: 1997-09-17 to 1998-03-24
#
# ------------------------------------------------------------
# Customer ID: FRANS
# Company: Franchi S.p.A.
# Contact: Paolo Accorti
# Location: Torino, Italy
# Total Orders: 6
# Total Quantity: 54
# Total Revenue: $1545.70
# Categories: Seafood, Condiments, Dairy Products, Produce, Confections
# Order Period: 1997-01-22 to 1998-04-30
#
# ------------------------------------------------------------
# Customer ID: FRANK
# Company: Frankenversand
# Contact: Peter Franken
# Location: München, Germany
# Total Orders: 15
# Total Quantity: 1525
# Total Revenue: $26656.56
# Categories: Meat/Poultry, Condiments, Beverages, Dairy Products, Produce, Confections, Grains/Cereals, Seafood
# Order Period: 1996-07-29 to 1998-04-09
#
# ------------------------------------------------------------
# Customer ID: FURIB
# Company: Furia Bacalhau e Frutos do Mar
# Contact: Lino Rodriguez
# Location: Lisboa, Portugal
# Total Orders: 8
# Total Quantity: 349
# Total Revenue: $6427.42
# Categories: Seafood, Condiments, Meat/Poultry, Dairy Products, Beverages, Confections, Grains/Cereals
# Order Period: 1996-10-14 to 1998-03-19
#
# ------------------------------------------------------------
# Customer ID: GROSR
# Company: GROSELLA-Restaurante
# Contact: Manuel Pereira
# Location: Caracas, Venezuela
# Total Orders: 2
# Total Quantity: 34
# Total Revenue: $1488.70
# Categories: Seafood, Dairy Products, Beverages, Meat/Poultry
# Order Period: 1996-07-30 to 1997-12-18
#
# ------------------------------------------------------------
# Customer ID: GALED
# Company: Galería del gastrónomo
# Contact: Eduardo Saavedra
# Location: Barcelona, Spain
# Total Orders: 5
# Total Quantity: 42
# Total Revenue: $836.70
# Categories: Seafood, Condiments, Grains/Cereals, Confections, Beverages
# Order Period: 1996-11-28 to 1998-03-05
#
# ------------------------------------------------------------
# Customer ID: GODOS
# Company: Godos Cocina Típica
# Contact: José Pedro Freyre
# Location: Sevilla, Spain
# Total Orders: 10
# Total Quantity: 395
# Total Revenue: $11446.36
# Categories: Meat/Poultry, Condiments, Beverages, Produce, Dairy Products, Confections, Grains/Cereals, Seafood
# Order Period: 1996-09-11 to 1998-04-21
#
# ------------------------------------------------------------
# Customer ID: GOURL
# Company: Gourmet Lanchonetes
# Contact: André Fonseca
# Location: Campinas, Brazil
# Total Orders: 9
# Total Quantity: 315
# Total Revenue: $8414.14
# Categories: Condiments, Dairy Products, Produce, Beverages, Grains/Cereals, Confections, Seafood
# Order Period: 1997-01-23 to 1998-04-24
#
# ------------------------------------------------------------
# Customer ID: GREAL
# Company: Great Lakes Food Market
# Contact: Howard Snyder
# Location: Eugene, USA
# Total Orders: 11
# Total Quantity: 345
# Total Revenue: $18507.45
# Categories: Condiments, Meat/Poultry, Produce, Dairy Products, Grains/Cereals, Beverages, Confections, Seafood
# Order Period: 1997-05-06 to 1998-04-30
#
# ------------------------------------------------------------
# Customer ID: HILAA
# Company: HILARION-Abastos
# Contact: Carlos Hernández
# Location: San Cristóbal, Venezuela
# Total Orders: 18
# Total Quantity: 1096
# Total Revenue: $22768.76
# Categories: Condiments, Meat/Poultry, Beverages, Dairy Products, Produce, Grains/Cereals, Confections, Seafood
# Order Period: 1996-07-16 to 1998-04-28
#
# ------------------------------------------------------------
# Customer ID: HANAR
# Company: Hanari Carnes
# Contact: Mario Pontes
# Location: Rio de Janeiro, Brazil
# Total Orders: 14
# Total Quantity: 839
# Total Revenue: $32841.37
# Categories: Condiments, Meat/Poultry, Dairy Products, Beverages, Produce, Grains/Cereals, Confections, Seafood
# Order Period: 1996-07-08 to 1998-04-27
#
# ------------------------------------------------------------
# Customer ID: HUNGC
# Company: Hungry Coyote Import Store
# Contact: Yoshi Latimer
# Location: Elgin, USA
# Total Orders: 5
# Total Quantity: 122
# Total Revenue: $3063.20
# Categories: Dairy Products, Meat/Poultry, Confections, Seafood, Produce
# Order Period: 1996-12-06 to 1997-09-08
#
# ------------------------------------------------------------
# Customer ID: HUNGO
# Company: Hungry Owl All-Night Grocers
# Contact: Patricia McKenna
# Location: Cork, Ireland
# Total Orders: 19
# Total Quantity: 1684
# Total Revenue: $49979.90
# Categories: Condiments, Meat/Poultry, Dairy Products, Beverages, Produce, Grains/Cereals, Confections, Seafood
# Order Period: 1996-09-05 to 1998-04-30
#
# ------------------------------------------------------------
# Customer ID: ISLAT
# Company: Island Trading
# Contact: Helen Bennett
# Location: Cowes, UK
# Total Orders: 10
# Total Quantity: 295
# Total Revenue: $6146.30
# Categories: Condiments, Meat/Poultry, Beverages, Dairy Products, Confections, Grains/Cereals, Seafood
# Order Period: 1996-09-26 to 1998-03-06
#
# ------------------------------------------------------------
# Customer ID: KOENE
# Company: Königlich Essen
# Contact: Philip Cramer
# Location: Brandenburg, Germany
# Total Orders: 14
# Total Quantity: 903
# Total Revenue: $30908.38
# Categories: Seafood, Meat/Poultry, Confections, Beverages, Produce, Dairy Products, Condiments
# Order Period: 1996-10-07 to 1998-04-16
#
# ------------------------------------------------------------
# Customer ID: LILAS
# Company: LILA-Supermercado
# Contact: Carlos González
# Location: Barquisimeto, Venezuela
# Total Orders: 14
# Total Quantity: 836
# Total Revenue: $16076.60
# Categories: Confections, Produce, Dairy Products, Beverages, Condiments, Meat/Poultry, Seafood, Grains/Cereals
# Order Period: 1996-08-16 to 1998-05-05
#
# ------------------------------------------------------------
# Customer ID: LINOD
# Company: LINO-Delicateses
# Contact: Felipe Izquierdo
# Location: I. de Margarita, Venezuela
# Total Orders: 12
# Total Quantity: 970
# Total Revenue: $16476.56
# Categories: Seafood, Confections, Grains/Cereals, Beverages, Dairy Products, Produce, Condiments, Meat/Poultry
# Order Period: 1997-01-06 to 1998-04-21
#
# ------------------------------------------------------------
# Customer ID: LACOR
# Company: La corne d'abondance
# Contact: Daniel Tonini
# Location: Versailles, France
# Total Orders: 4
# Total Quantity: 83
# Total Revenue: $1992.05
# Categories: Meat/Poultry, Beverages, Produce, Dairy Products, Confections, Grains/Cereals, Seafood
# Order Period: 1998-01-29 to 1998-03-24
#
# ------------------------------------------------------------
# Customer ID: LAMAI
# Company: La maison d'Asie
# Contact: Annette Roulet
# Location: Toulouse, France
# Total Orders: 14
# Total Quantity: 442
# Total Revenue: $9328.20
# Categories: Meat/Poultry, Condiments, Dairy Products, Beverages, Produce, Grains/Cereals, Confections, Seafood
# Order Period: 1996-11-11 to 1998-04-27
#
# ------------------------------------------------------------
# Customer ID: LAUGB
# Company: Laughing Bacchus Wine Cellars
# Contact: Yoshi Tannamuri
# Location: Vancouver, Canada
# Total Orders: 3
# Total Quantity: 62
# Total Revenue: $522.50
# Categories: Seafood, Confections, Beverages, Grains/Cereals, Condiments
# Order Period: 1997-04-03 to 1998-01-01
#
# ------------------------------------------------------------
# Customer ID: LAZYK
# Company: Lazy K Kountry Store
# Contact: John Steel
# Location: Walla Walla, USA
# Total Orders: 2
# Total Quantity: 20
# Total Revenue: $357.00
# Categories: Seafood, Dairy Products
# Order Period: 1997-03-21 to 1997-05-22
#
# ------------------------------------------------------------
# Customer ID: LEHMS
# Company: Lehmanns Marktstand
# Contact: Renate Messner
# Location: Frankfurt a.M., Germany
# Total Orders: 15
# Total Quantity: 794
# Total Revenue: $19261.41
# Categories: Condiments, Meat/Poultry, Dairy Products, Beverages, Grains/Cereals, Confections, Seafood
# Order Period: 1996-08-13 to 1998-05-05
#
# ------------------------------------------------------------
# Customer ID: LETSS
# Company: Let's Stop N Shop
# Contact: Jaime Yorres
# Location: San Francisco, USA
# Total Orders: 4
# Total Quantity: 181
# Total Revenue: $3076.47
# Categories: Seafood, Condiments, Meat/Poultry, Confections, Grains/Cereals, Beverages
# Order Period: 1997-06-25 to 1998-02-12
#
# ------------------------------------------------------------
# Customer ID: LONEP
# Company: Lonesome Pine Restaurant
# Contact: Fran Wilson
# Location: Portland, USA
# Total Orders: 8
# Total Quantity: 134
# Total Revenue: $4258.60
# Categories: Seafood, Grains/Cereals, Confections, Beverages, Produce, Dairy Products, Meat/Poultry
# Order Period: 1996-09-17 to 1998-04-13
#
# ------------------------------------------------------------
# Customer ID: MAGAA
# Company: Magazzini Alimentari Riuniti
# Contact: Giovanni Rovelli
# Location: Bergamo, Italy
# Total Orders: 10
# Total Quantity: 433
# Total Revenue: $7176.22
# Categories: Beverages, Dairy Products, Grains/Cereals, Seafood, Condiments, Confections
# Order Period: 1996-08-07 to 1998-03-16
#
# ------------------------------------------------------------
# Customer ID: MAISD
# Company: Maison Dewey
# Contact: Catherine Dewey
# Location: Bruxelles, Belgium
# Total Orders: 7
# Total Quantity: 320
# Total Revenue: $9736.08
# Categories: Seafood, Condiments, Grains/Cereals, Confections, Dairy Products, Produce, Beverages, Meat/Poultry
# Order Period: 1997-05-07 to 1998-04-07
#
# ------------------------------------------------------------
# Customer ID: MORGK
# Company: Morgenstern Gesundkost
# Contact: Alexander Feuer
# Location: Leipzig, Germany
# Total Orders: 5
# Total Quantity: 172
# Total Revenue: $5042.20
# Categories: Seafood, Confections, Condiments, Produce, Dairy Products, Beverages
# Order Period: 1996-08-09 to 1998-03-12
#
# ------------------------------------------------------------
# Customer ID: MEREP
# Company: Mère Paillarde
# Contact: Jean Fresnière
# Location: Montréal, Canada
# Total Orders: 13
# Total Quantity: 966
# Total Revenue: $28872.19
# Categories: Seafood, Confections, Grains/Cereals, Dairy Products, Beverages, Produce, Condiments, Meat/Poultry
# Order Period: 1996-10-17 to 1997-10-30
#
# ------------------------------------------------------------
# Customer ID: NORTS
# Company: North/South
# Contact: Simon Crowther
# Location: London, UK
# Total Orders: 3
# Total Quantity: 30
# Total Revenue: $649.00
# Categories: Beverages, Dairy Products, Grains/Cereals
# Order Period: 1997-04-24 to 1998-04-29
#
# ------------------------------------------------------------
# Customer ID: OCEAN
# Company: Océano Atlántico Ltda.
# Contact: Yvonne Moncada
# Location: Buenos Aires, Argentina
# Total Orders: 5
# Total Quantity: 132
# Total Revenue: $3460.20
# Categories: Seafood, Condiments, Dairy Products, Produce, Beverages, Confections
# Order Period: 1997-01-09 to 1998-03-30
#
# ------------------------------------------------------------
# Customer ID: OLDWO
# Company: Old World Delicatessen
# Contact: Rene Phillips
# Location: Anchorage, USA
# Total Orders: 10
# Total Quantity: 603
# Total Revenue: $15177.46
# Categories: Seafood, Condiments, Grains/Cereals, Confections, Beverages, Dairy Products, Produce, Meat/Poultry
# Order Period: 1996-09-13 to 1998-04-20
#
# ------------------------------------------------------------
# Customer ID: OTTIK
# Company: Ottilies Käseladen
# Contact: Henriette Pfalzheim
# Location: Köln, Germany
# Total Orders: 10
# Total Quantity: 639
# Total Revenue: $12496.20
# Categories: Condiments, Seafood, Meat/Poultry, Grains/Cereals, Confections, Produce, Dairy Products, Beverages
# Order Period: 1996-07-19 to 1998-04-14
#
# ------------------------------------------------------------
# Customer ID: PERIC
# Company: Pericles Comidas clásicas
# Contact: Guillermo Fernández
# Location: México D.F., Mexico
# Total Orders: 6
# Total Quantity: 208
# Total Revenue: $4242.20
# Categories: Seafood, Beverages, Produce, Dairy Products, Grains/Cereals, Meat/Poultry
# Order Period: 1996-10-04 to 1998-05-05
#
# ------------------------------------------------------------
# Customer ID: PICCO
# Company: Piccolo und mehr
# Contact: Georg Pipps
# Location: Salzburg, Austria
# Total Orders: 10
# Total Quantity: 624
# Total Revenue: $23128.86
# Categories: Confections, Grains/Cereals, Seafood, Meat/Poultry, Condiments, Dairy Products, Beverages, Produce
# Order Period: 1996-11-13 to 1998-04-27
#
# ------------------------------------------------------------
# Customer ID: PRINI
# Company: Princesa Isabel Vinhos
# Contact: Isabel de Castro
# Location: Lisboa, Portugal
# Total Orders: 5
# Total Quantity: 184
# Total Revenue: $5044.94
# Categories: Grains/Cereals, Beverages, Condiments, Confections, Meat/Poultry, Produce
# Order Period: 1996-10-23 to 1998-04-08
#
# ------------------------------------------------------------
# Customer ID: QUICK
# Company: QUICK-Stop
# Contact: Horst Kloss
# Location: Cunewalde, Germany
# Total Orders: 28
# Total Quantity: 3961
# Total Revenue: $110277.30
# Categories: Seafood, Confections, Grains/Cereals, Dairy Products, Beverages, Produce, Meat/Poultry, Condiments
# Order Period: 1996-08-05 to 1998-04-14
#
# ------------------------------------------------------------
# Customer ID: QUEDE
# Company: Que Delícia
# Contact: Bernardo Batista
# Location: Rio de Janeiro, Brazil
# Total Orders: 9
# Total Quantity: 394
# Total Revenue: $6664.81
# Categories: Beverages, Produce, Dairy Products, Condiments, Meat/Poultry, Seafood, Confections
# Order Period: 1996-07-19 to 1998-03-31
#
# ------------------------------------------------------------
# Customer ID: QUEEN
# Company: Queen Cozinha
# Contact: Lúcia Carvalho
# Location: Sao Paulo, Brazil
# Total Orders: 13
# Total Quantity: 1031
# Total Revenue: $25717.50
# Categories: Meat/Poultry, Seafood, Condiments, Grains/Cereals, Confections, Produce, Dairy Products, Beverages
# Order Period: 1996-12-04 to 1998-05-04
#
# ------------------------------------------------------------
# Customer ID: RANCH
# Company: Rancho grande
# Contact: Sergio Gutiérrez
# Location: Buenos Aires, Argentina
# Total Orders: 5
# Total Quantity: 92
# Total Revenue: $2844.10
# Categories: Condiments, Seafood, Grains/Cereals, Confections, Produce, Beverages, Dairy Products
# Order Period: 1997-02-17 to 1998-04-13
#
# ------------------------------------------------------------
# Customer ID: RATTC
# Company: Rattlesnake Canyon Grocery
# Contact: Paula Wilson
# Location: Albuquerque, USA
# Total Orders: 18
# Total Quantity: 1383
# Total Revenue: $51097.80
# Categories: Condiments, Meat/Poultry, Dairy Products, Produce, Beverages, Grains/Cereals, Confections, Seafood
# Order Period: 1996-07-22 to 1998-05-06
#
# ------------------------------------------------------------
# Customer ID: REGGC
# Company: Reggiani Caseifici
# Contact: Maurizio Moroni
# Location: Reggio Emilia, Italy
# Total Orders: 12
# Total Quantity: 335
# Total Revenue: $7048.24
# Categories: Seafood, Confections, Grains/Cereals, Produce, Dairy Products, Beverages, Meat/Poultry, Condiments
# Order Period: 1996-08-23 to 1998-04-30
#
# ------------------------------------------------------------
# Customer ID: RICAR
# Company: Ricardo Adocicados
# Contact: Janete Limeira
# Location: Rio de Janeiro, Brazil
# Total Orders: 11
# Total Quantity: 660
# Total Revenue: $12450.80
# Categories: Condiments, Meat/Poultry, Beverages, Dairy Products, Confections, Grains/Cereals, Seafood
# Order Period: 1996-08-22 to 1998-04-29
#
# ------------------------------------------------------------
# Customer ID: RICSU
# Company: Richter Supermarkt
# Contact: Michael Holz
# Location: Genève, Switzerland
# Total Orders: 10
# Total Quantity: 810
# Total Revenue: $19343.78
# Categories: Confections, Grains/Cereals, Seafood, Meat/Poultry, Condiments, Beverages, Dairy Products, Produce
# Order Period: 1996-07-12 to 1998-05-06
#
# ------------------------------------------------------------
# Customer ID: ROMEY
# Company: Romero y tomillo
# Contact: Alejandra Camino
# Location: Madrid, Spain
# Total Orders: 5
# Total Quantity: 91
# Total Revenue: $1467.29
# Categories: Beverages, Grains/Cereals, Seafood, Dairy Products, Confections, Meat/Poultry
# Order Period: 1996-08-14 to 1998-04-09
#
# ------------------------------------------------------------
# Customer ID: SANTG
# Company: Santé Gourmet
# Contact: Jonas Bergulfsen
# Location: Stavern, Norway
# Total Orders: 6
# Total Quantity: 161
# Total Revenue: $5735.15
# Categories: Seafood, Condiments, Confections, Beverages, Produce, Dairy Products, Meat/Poultry
# Order Period: 1996-12-18 to 1998-04-10
#
# ------------------------------------------------------------
# Customer ID: SAVEA
# Company: Save-a-lot Markets
# Contact: Jose Pavarotti
# Location: Boise, USA
# Total Orders: 31
# Total Quantity: 4958
# Total Revenue: $104361.95
# Categories: Condiments, Meat/Poultry, Produce, Beverages, Dairy Products, Grains/Cereals, Confections, Seafood
# Order Period: 1996-10-08 to 1998-05-01
#
# ------------------------------------------------------------
# Customer ID: SEVES
# Company: Seven Seas Imports
# Contact: Hari Kumar
# Location: London, UK
# Total Orders: 9
# Total Quantity: 818
# Total Revenue: $16215.32
# Categories: Meat/Poultry, Produce, Dairy Products, Beverages, Grains/Cereals, Confections, Seafood
# Order Period: 1996-11-21 to 1998-02-04
#
# ------------------------------------------------------------
# Customer ID: SIMOB
# Company: Simons bistro
# Contact: Jytte Petersen
# Location: Kobenhavn, Denmark
# Total Orders: 7
# Total Quantity: 378
# Total Revenue: $16817.10
# Categories: Seafood, Confections, Beverages, Produce, Dairy Products, Condiments, Meat/Poultry
# Order Period: 1996-10-29 to 1998-05-06
#
# ------------------------------------------------------------
# Customer ID: SPLIR
# Company: Split Rail Beer & Ale
# Contact: Art Braunschweiger
# Location: Lander, USA
# Total Orders: 9
# Total Quantity: 327
# Total Revenue: $11441.63
# Categories: Meat/Poultry, Condiments, Dairy Products, Beverages, Produce, Grains/Cereals, Confections, Seafood
# Order Period: 1996-08-01 to 1998-03-25
#
# ------------------------------------------------------------
# Customer ID: SPECD
# Company: Spécialités du monde
# Contact: Dominique Perrier
# Location: Paris, France
# Total Orders: 4
# Total Quantity: 48
# Total Revenue: $2423.35
# Categories: Seafood, Beverages, Dairy Products, Confections
# Order Period: 1997-11-12 to 1998-04-22
#
# ------------------------------------------------------------
# Customer ID: SUPRD
# Company: Suprêmes délices
# Contact: Pascale Cartrain
# Location: Charleroi, Belgium
# Total Orders: 12
# Total Quantity: 1072
# Total Revenue: $24088.78
# Categories: Meat/Poultry, Condiments, Dairy Products, Produce, Beverages, Confections, Grains/Cereals, Seafood
# Order Period: 1996-07-09 to 1998-04-21
#
# ------------------------------------------------------------
# Customer ID: THEBI
# Company: The Big Cheese
# Contact: Liz Nixon
# Location: Portland, USA
# Total Orders: 4
# Total Quantity: 46
# Total Revenue: $3361.00
# Categories: Condiments, Confections, Beverages, Dairy Products, Seafood
# Order Period: 1996-09-20 to 1998-04-01
#
# ------------------------------------------------------------
# Customer ID: THECR
# Company: The Cracker Box
# Contact: Liu Wong
# Location: Butte, USA
# Total Orders: 3
# Total Quantity: 59
# Total Revenue: $1947.24
# Categories: Meat/Poultry, Condiments, Produce, Seafood, Beverages, Grains/Cereals
# Order Period: 1997-08-07 to 1998-04-06
#
# ------------------------------------------------------------
# Customer ID: TOMSP
# Company: Toms Spezialitäten
# Contact: Karin Josephs
# Location: Münster, Germany
# Total Orders: 6
# Total Quantity: 253
# Total Revenue: $4778.14
# Categories: Seafood, Confections, Grains/Cereals, Produce, Beverages, Dairy Products
# Order Period: 1996-07-05 to 1998-03-23
#
# ------------------------------------------------------------
# Customer ID: TORTU
# Company: Tortuga Restaurante
# Contact: Miguel Angel Paolino
# Location: México D.F., Mexico
# Total Orders: 10
# Total Quantity: 384
# Total Revenue: $10812.15
# Categories: Meat/Poultry, Condiments, Beverages, Dairy Products, Produce, Confections, Seafood
# Order Period: 1996-08-08 to 1998-05-04
#
# ------------------------------------------------------------
# Customer ID: TRADH
# Company: Tradição Hipermercados
# Contact: Anabela Domingues
# Location: Sao Paulo, Brazil
# Total Orders: 6
# Total Quantity: 251
# Total Revenue: $6850.66
# Categories: Condiments, Confections, Meat/Poultry, Dairy Products, Beverages, Seafood
# Order Period: 1996-08-28 to 1998-01-19
#
# ------------------------------------------------------------
# Customer ID: TRAIH
# Company: Trail's Head Gourmet Provisioners
# Contact: Helvetius Nagy
# Location: Kirkland, USA
# Total Orders: 3
# Total Quantity: 89
# Total Revenue: $1571.20
# Categories: Condiments, Dairy Products, Beverages, Seafood, Confections, Grains/Cereals
# Order Period: 1997-06-19 to 1998-01-08
#
# ------------------------------------------------------------
# Customer ID: VAFFE
# Company: Vaffeljernet
# Contact: Palle Ibsen
# Location: Århus, Denmark
# Total Orders: 11
# Total Quantity: 792
# Total Revenue: $15843.92
# Categories: Meat/Poultry, Condiments, Seafood, Grains/Cereals, Confections, Produce, Beverages, Dairy Products
# Order Period: 1996-11-28 to 1998-04-02
#
# ------------------------------------------------------------
# Customer ID: VICTE
# Company: Victuailles en stock
# Contact: Mary Saveley
# Location: Lyon, France
# Total Orders: 10
# Total Quantity: 434
# Total Revenue: $9182.43
# Categories: Seafood, Confections, Grains/Cereals, Dairy Products, Produce, Beverages, Condiments, Meat/Poultry
# Order Period: 1996-07-08 to 1998-01-23
#
# ------------------------------------------------------------
# Customer ID: VINET
# Company: Vins et alcools Chevalier
# Contact: Paul Henriot
# Location: Reims, France
# Total Orders: 5
# Total Quantity: 98
# Total Revenue: $1480.00
# Categories: Seafood, Grains/Cereals, Dairy Products
# Order Period: 1996-07-04 to 1997-11-12
#
# ------------------------------------------------------------
# Customer ID: WARTH
# Company: Wartian Herkku
# Contact: Pirkko Koskitalo
# Location: Oulu, Finland
# Total Orders: 15
# Total Quantity: 737
# Total Revenue: $15648.70
# Categories: Meat/Poultry, Seafood, Condiments, Grains/Cereals, Confections, Produce, Beverages, Dairy Products
# Order Period: 1996-07-26 to 1998-04-15
#
# ------------------------------------------------------------
# Customer ID: WELLI
# Company: Wellington Importadora
# Contact: Paula Parente
# Location: Resende, Brazil
# Total Orders: 9
# Total Quantity: 267
# Total Revenue: $6068.20
# Categories: Seafood, Confections, Grains/Cereals, Beverages, Dairy Products, Condiments, Meat/Poultry
# Order Period: 1996-07-15 to 1998-03-09
#
# ------------------------------------------------------------
# Customer ID: WHITC
# Company: White Clover Markets
# Contact: Karl Jablonski
# Location: Seattle, USA
# Total Orders: 14
# Total Quantity: 1063
# Total Revenue: $27363.60
# Categories: Dairy Products, Beverages, Produce, Condiments, Meat/Poultry, Seafood, Grains/Cereals, Confections
# Order Period: 1996-07-31 to 1998-05-01
#
# ------------------------------------------------------------
# Customer ID: WILMK
# Company: Wilman Kala
# Contact: Matti Karttunen
# Location: Helsinki, Finland
# Total Orders: 7
# Total Quantity: 148
# Total Revenue: $3161.35
# Categories: Seafood, Confections, Grains/Cereals, Produce, Beverages, Dairy Products, Meat/Poultry, Condiments
# Order Period: 1997-07-30 to 1998-04-07
#
# ------------------------------------------------------------
# Customer ID: WOLZA
# Company: Wolski  Zajazd
# Contact: Zbyszek Piestrzeniewicz
# Location: Warszawa, Poland
# Total Orders: 7
# Total Quantity: 205
# Total Revenue: $3531.95
# Categories: Confections, Seafood, Meat/Poultry, Condiments, Beverages, Produce, Dairy Products
# Order Period: 1996-12-05 to 1998-04-23

# %%
# Final verification - show all collections and their counts
print("=== Final Database Summary ===")
print(f"\nDatabase: Northwind")
print("\nCollections:")
for collection_name in sorted(db.list_collection_names()):
    count = db[collection_name].count_documents({})
    print(f"  - {collection_name}: {count} documents")
# Out:
# === Final Database Summary ===
#
# Database: Northwind
#
# Collections:
#   - categories: 8 documents
#   - customer_sales_summary: 89 documents
#   - customers: 91 documents
#   - employees: 9 documents
#   - orders: 830 documents
#   - products: 77 documents
#   - suppliers: 29 documents

# %%
# Close the connection
client.close()
print("MongoDB connection closed.")
# Out:
# MongoDB connection closed.

# %% [markdown]
# # End of Question 1 - MongoDB Northwind Database
